# %% [markdown]
# # Text Similarity
#
# My team and I decided to solve Fake Detection task through finding text similarities of the current news and news from white-list sources

# %% [markdown]
# ## Imports

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
# Requirement already satisfied: pyyaml>=5.1 in d:\anaconda\lib\site-packages (from transformers) (5.4.1)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in d:\anaconda\lib\site-packages (from transformers) (4.59.0)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda\lib\site-packages (from transformers) (1.20.1)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from transformers) (20.9)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-win_amd64.whl (3.3 MB)
# Requirement already satisfied: regex!=2019.12.17 in d:\anaconda\lib\site-packages (from transformers) (2021.4.4)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anaconda\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\anaconda\lib\site-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->transformers) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->transformers) (2020.12.5)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.7.0 tokenizers-0.12.1 transformers-4.19.2

# %%
import pandas as pd
import numpy as np
import torch

from nltk.corpus import stopwords

from sklearn.metrics.pairwise import cosine_similarity, manhattan_distances, euclidean_distances
from sklearn.feature_extraction.text import TfidfVectorizer

from transformers import AutoTokenizer, AutoModel

# %% [markdown]
# ## Loading data

# %%
data = pd.read_json("data/ixbt.json")

# %%
data.head()
# Out:
#                                                title  \
# 0  Первый на рынке смартфон с новой 108-мегапиксе...
# 1  Стоечные сетевые хранилища Qnap TS-873AeU пост...
# 2  Китайский космический корабль «Тяньчжоу-2» сош...
# 3  Зачем делать новый смартфон лучше старого? Sam...
# 4  Ford и GM остановят производство на двух завод...
#
#                                             subtitle  \
# 0                            Он получит экран AMOLED
# 1               Они рассчитаны на восемь накопителей
# 2  Он использовался для доставки грузов на китайс...
# 3                    Платформа Exynos 850 сохранится
# 4  Мировая автомобильная промышленность испытывае...
#
#                                                  url              time  \
# 0  https://www.ixbt.com/news/2022/04/01/108-realm...  01.04.2022 23:18
# 1  https://www.ixbt.com/news/2022/04/01/qnap-ts-8...  01.04.2022 21:21
# 2  https://www.ixbt.com/news/2022/04/01/kitajskij...  01.04.2022 21:15
# 3  https://www.ixbt.com/news/2022/04/01/samsung-g...  01.04.2022 21:15
# 4  https://www.ixbt.com/news/2022/04/01/ford-i-gm...  01.04.2022 20:51
#
#                                                 text        tags       sources
# 0  Информации о смартфоне Realme 9 4G, который пе...    [Realme]  [Gizmochina]
# 1  Компания Qnap Systems представила серию хранил...     [Qnap ]        [Qnap]
# 2  Как пишет Интерфакс со ссылкой на Центральное ...          []   [Интерфакс]
# 3  Компания Samsung готовит ещё один очень доступ...   [Samsung]   [GSM Arena]
# 4  Компании Ford Motor и General Motors (GM) на с...  [Ford, GM]     [Reuters]

# %%
data.shape
# Out:
# (4044, 7)

# %% [markdown]
# ## RuBERT

# %%
tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased-conversational")
model = AutoModel.from_pretrained("DeepPavlov/rubert-base-cased-conversational")
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased-conversational were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Preprocessing
tokens = {'input_ids': [], 'attention_mask': []}

for sentence in data.text[:20]:
    # encode each sentence and append to dictionary
    new_tokens = tokenizer.encode_plus(sentence, max_length=512,
                                       truncation=True, padding='max_length',
                                       return_tensors='pt')
    tokens['input_ids'].append(new_tokens['input_ids'][0])
    tokens['attention_mask'].append(new_tokens['attention_mask'][0])

# reformat list of tensors into single tensor
tokens['input_ids'] = torch.stack(tokens['input_ids'])
tokens['attention_mask'] = torch.stack(tokens['attention_mask'])

# %%
idfs_score = dict()

for line in tokens['input_ids']:
    u_line_tokens = torch.unique(line)
    for token in u_line_tokens:
        try:
            idfs_score[token.item()] += 1
        except KeyError:
            idfs_score[token.item()] = 1

# %%
idfs_score = {item[0]: np.log(tokens['input_ids'].shape[0] / item[1]) for item in idfs_score.items()}

# %%
# %%time
# Using model
outputs = model(**tokens)
# Out:
# Wall time: 56.6 s

# %%
outputs.keys()
# Out:
# odict_keys(['last_hidden_state', 'pooler_output'])

# %%
embeddings = outputs.last_hidden_state
embeddings
# Out:
# tensor([[[-0.0123,  0.5137,  0.7827,  ...,  1.2225,  0.5043, -0.3281],
#          [-0.3710, -0.4433,  1.1205,  ...,  1.0690,  1.4072, -0.4002],
#          [-0.9653, -0.4438,  0.9468,  ...,  0.3695,  0.4446, -0.8369],
#          ...,
#          [-0.6415,  0.4246,  1.6744,  ...,  1.6243,  0.9710, -0.7326],
#          [-0.6097,  0.2388,  1.8754,  ...,  1.5156,  0.5597, -0.7159],
#          [-0.4524,  0.0370,  1.3068,  ...,  1.3169,  0.5921,  0.1661]],
#
#         [[-0.8850, -0.1318, -0.2900,  ...,  0.8480,  0.7990, -0.4450],
#          [-0.6553, -0.4653,  0.5654,  ...,  1.3518,  0.4975, -0.9408],
#          [-0.5849,  0.3679,  0.8588,  ..., -0.8018,  0.4140, -1.5484],
#          ...,
#          [-0.7501, -0.5068, -0.2334,  ..., -0.0671,  1.4792, -0.2848],
#          [-1.0348, -0.5302,  0.3802,  ..., -0.2080,  1.5405, -0.5321],
#          [-0.3353, -0.0545, -0.1519,  ...,  1.0112,  0.9447, -0.1615]],
#
#         [[-0.2809,  0.4852,  0.4439,  ...,  0.6116,  0.4189, -0.2743],
#          [-0.6677,  0.3747,  0.2640,  ...,  0.9338,  1.3214,  1.2783],
#          [-0.6782,  0.0100,  1.4601,  ...,  1.0919,  1.1776, -0.0762],
#          ...,
#          [ 0.1898,  0.4581,  1.0852,  ...,  0.7016,  0.4948,  0.1624],
#          [-0.2837,  0.6647,  1.2663,  ...,  0.3451,  0.5479, -0.3689],
#          [-0.6379,  0.5258,  1.6389,  ...,  0.5697,  0.1694,  0.3158]],
#
#         ...,
#
#         [[-0.3525,  0.6437,  0.4512,  ...,  0.6421,  0.4762, -0.4022],
#          [-0.8946,  0.0680,  1.6690,  ...,  1.4749,  0.4864, -0.9318],
#          [-1.0159,  0.0198,  0.5478,  ..., -0.1178,  0.2354, -0.6203],
#          ...,
#          [-0.7195,  0.3281,  0.9472,  ...,  0.0306,  0.8870, -0.4705],
#          [-0.7943,  0.6927,  1.0972,  ...,  0.0601,  0.6948, -0.3516],
#          [-0.3329,  0.4991,  0.9819,  ...,  0.6378,  1.0537,  0.0329]],
#
#         [[ 0.0469,  0.2865,  0.5875,  ...,  0.6303,  0.2873, -0.8157],
#          [-0.5099,  0.5875, -0.0993,  ...,  0.7831,  1.4584,  0.2874],
#          [-1.1397, -0.6308,  0.4401,  ...,  1.0298,  0.9421, -0.1912],
#          ...,
#          [-0.2049,  0.3707,  0.7782,  ...,  0.4460,  0.0184, -0.1947],
#          [-0.7028,  0.5883,  1.2124,  ...,  0.1168,  0.5334, -0.2617],
#          [-0.2623,  0.2873,  0.7379,  ...,  0.8964,  0.3582,  0.0926]],
#
#         [[-0.2530,  0.2479,  0.6474,  ...,  0.7337,  0.4951, -0.4631],
#          [-0.6421,  0.0743,  0.7806,  ...,  0.4576, -0.4231, -0.4788],
#          [-1.0898,  0.3169,  1.0762,  ...,  0.8687, -0.1064, -0.6827],
#          ...,
#          [-0.1474, -0.1434,  0.7860,  ...,  0.8326,  0.9558, -0.5118],
#          [-0.4712, -0.0626,  1.1009,  ...,  0.2852,  0.9573, -0.6146],
#          [-0.7144, -0.0054,  0.5563,  ...,  1.1879,  0.9534, -0.1475]]],
#        grad_fn=<NativeLayerNormBackward0>)

# %%
embeddings.shape
# Out:
# torch.Size([20, 512, 768])

# %%
attention_mask = tokens['attention_mask']
# Reshaping attenion mask
mask = attention_mask.unsqueeze(-1).expand(embeddings.size()).float()
# Applying attention mask
masked_embeddings = embeddings * mask

# Getting average vector
summed = torch.sum(masked_embeddings, 1)

summed_mask = torch.clamp(mask.sum(1), min=1e-9)

text_vectors = summed / summed_mask

# %%
text_vectors
# Out:
# tensor([[-0.4340, -0.2074,  0.6403,  ...,  1.0288,  0.5380, -0.2410],
#         [-0.5237, -0.2945,  0.0657,  ...,  0.8257,  0.7562, -0.2475],
#         [-0.2741, -0.1203,  0.4638,  ...,  0.7611,  0.2944,  0.0548],
#         ...,
#         [-0.4745,  0.1994,  0.7839,  ...,  0.5246,  0.3847, -0.3414],
#         [-0.3081, -0.2650,  0.6648,  ...,  0.6837,  0.1493, -0.2319],
#         [-0.5242, -0.1639,  0.6322,  ...,  0.8743,  0.3982, -0.2809]],
#        grad_fn=<DivBackward0>)

# %%
text_vectors.shape
# Out:
# torch.Size([20, 768])

# %%
cosine_similarities_dct = dict()

for i in range(embeddings.shape[0]):
    for j in range(i + 1, embeddings.shape[0]):
        first_vector = text_vectors[i].detach().numpy().reshape(1, -1)
        second_vector = text_vectors[j].detach().numpy().reshape(1, -1)
        cosine_similarities_dct[f'{i} - {j}'] = cosine_similarity(first_vector, second_vector)[0][0]

# %%
for pair, similarity in sorted(cosine_similarities_dct.items(), key=lambda x: x[1], reverse=True):
    print(f"Pair {pair} -> {similarity}")
# Out:
# Pair 3 - 17 -> 0.9160645008087158
# Pair 3 - 19 -> 0.9086664915084839
# Pair 3 - 18 -> 0.8823859691619873
# Pair 17 - 19 -> 0.8762884140014648
# Pair 8 - 13 -> 0.8704392910003662
# Pair 3 - 7 -> 0.8688899278640747
# Pair 18 - 19 -> 0.8605533838272095
# Pair 11 - 15 -> 0.8589591383934021
# Pair 11 - 13 -> 0.8478221893310547
# Pair 1 - 13 -> 0.8468063473701477
# Pair 0 - 3 -> 0.8467146158218384
# Pair 7 - 17 -> 0.843827486038208
# Pair 13 - 15 -> 0.8434358239173889
# Pair 0 - 17 -> 0.8427705764770508
# Pair 4 - 15 -> 0.8415980935096741
# Pair 0 - 15 -> 0.8410001993179321
# Pair 10 - 18 -> 0.8375211954116821
# Pair 4 - 11 -> 0.8359225988388062
# Pair 7 - 18 -> 0.834682822227478
# Pair 16 - 18 -> 0.8337271213531494
# Pair 17 - 18 -> 0.8276875019073486
# Pair 1 - 8 -> 0.8276330232620239
# Pair 6 - 18 -> 0.8265410661697388
# Pair 6 - 16 -> 0.825156033039093
# Pair 0 - 19 -> 0.8242336511611938
# Pair 3 - 16 -> 0.8226326704025269
# Pair 8 - 19 -> 0.8197687864303589
# Pair 16 - 19 -> 0.8197057843208313
# Pair 0 - 11 -> 0.8193777203559875
# Pair 7 - 19 -> 0.8184603452682495
# Pair 12 - 16 -> 0.8166184425354004
# Pair 9 - 15 -> 0.8146833181381226
# Pair 6 - 12 -> 0.8138136267662048
# Pair 9 - 11 -> 0.8136051297187805
# Pair 12 - 15 -> 0.8131295442581177
# Pair 10 - 19 -> 0.8122870922088623
# Pair 1 - 11 -> 0.8119293451309204
# Pair 3 - 10 -> 0.8118465542793274
# Pair 5 - 16 -> 0.8114737272262573
# Pair 0 - 13 -> 0.8103945255279541
# Pair 5 - 6 -> 0.8088178038597107
# Pair 15 - 16 -> 0.8082720041275024
# Pair 13 - 19 -> 0.8054486513137817
# Pair 6 - 10 -> 0.8052173256874084
# Pair 8 - 15 -> 0.8040462732315063
# Pair 8 - 17 -> 0.8017207384109497
# Pair 0 - 1 -> 0.8000834584236145
# Pair 15 - 18 -> 0.7995166778564453
# Pair 4 - 6 -> 0.7984554171562195
# Pair 12 - 13 -> 0.7983786463737488
# Pair 11 - 18 -> 0.7964811325073242
# Pair 0 - 18 -> 0.7945979833602905
# Pair 11 - 19 -> 0.7940629124641418
# Pair 3 - 15 -> 0.794015645980835
# Pair 4 - 13 -> 0.7938534021377563
# Pair 0 - 8 -> 0.7936135530471802
# Pair 8 - 11 -> 0.7920776605606079
# Pair 2 - 15 -> 0.7901487946510315
# Pair 15 - 19 -> 0.7887246012687683
# Pair 6 - 11 -> 0.7882837057113647
# Pair 3 - 8 -> 0.7878288626670837
# Pair 6 - 15 -> 0.7877596020698547
# Pair 6 - 8 -> 0.7870615720748901
# Pair 16 - 17 -> 0.7868943214416504
# Pair 3 - 11 -> 0.7858376502990723
# Pair 7 - 11 -> 0.7843978404998779
# Pair 12 - 14 -> 0.7830785512924194
# Pair 1 - 19 -> 0.7829297780990601
# Pair 4 - 9 -> 0.780617356300354
# Pair 1 - 15 -> 0.7805182933807373
# Pair 14 - 15 -> 0.778448760509491
# Pair 6 - 9 -> 0.7774369716644287
# Pair 3 - 6 -> 0.7759658098220825
# Pair 9 - 18 -> 0.7752416729927063
# Pair 10 - 16 -> 0.7749227285385132
# Pair 0 - 7 -> 0.7740520238876343
# Pair 5 - 12 -> 0.7731567621231079
# Pair 15 - 17 -> 0.7724671363830566
# Pair 13 - 18 -> 0.7717453241348267
# Pair 11 - 12 -> 0.7717025876045227
# Pair 7 - 10 -> 0.7715562582015991
# Pair 6 - 19 -> 0.7703286409378052
# Pair 9 - 13 -> 0.7702195644378662
# Pair 0 - 4 -> 0.7697173953056335
# Pair 8 - 10 -> 0.7692309021949768
# Pair 1 - 3 -> 0.7691951990127563
# Pair 1 - 17 -> 0.7687779664993286
# Pair 0 - 16 -> 0.7683930397033691
# Pair 8 - 18 -> 0.7670203447341919
# Pair 3 - 13 -> 0.7668932676315308
# Pair 10 - 11 -> 0.7662246227264404
# Pair 10 - 15 -> 0.7654334902763367
# Pair 13 - 16 -> 0.7651816606521606
# Pair 4 - 10 -> 0.7648624777793884
# Pair 11 - 16 -> 0.7641903758049011
# Pair 6 - 14 -> 0.7636613845825195
# Pair 1 - 4 -> 0.7631619572639465
# Pair 11 - 17 -> 0.7631251215934753
# Pair 6 - 13 -> 0.763114333152771
# Pair 0 - 12 -> 0.7610965967178345
# Pair 5 - 11 -> 0.7606087923049927
# Pair 10 - 13 -> 0.7601795196533203
# Pair 9 - 14 -> 0.7598093152046204
# Pair 8 - 16 -> 0.7597986459732056
# Pair 13 - 17 -> 0.759192943572998
# Pair 4 - 12 -> 0.7562446594238281
# Pair 2 - 12 -> 0.7554193735122681
# Pair 9 - 12 -> 0.7552058696746826
# Pair 8 - 12 -> 0.7539462447166443
# Pair 6 - 17 -> 0.7536322474479675
# Pair 9 - 19 -> 0.7535840272903442
# Pair 8 - 9 -> 0.7533918619155884
# Pair 11 - 14 -> 0.7509377002716064
# Pair 5 - 18 -> 0.7508832216262817
# Pair 9 - 16 -> 0.750505805015564
# Pair 10 - 12 -> 0.750125527381897
# Pair 2 - 11 -> 0.749282956123352
# Pair 4 - 18 -> 0.747873067855835
# Pair 2 - 6 -> 0.7476949691772461
# Pair 4 - 8 -> 0.7466743588447571
# Pair 1 - 12 -> 0.746095597743988
# Pair 7 - 16 -> 0.7456966638565063
# Pair 10 - 17 -> 0.745286226272583
# Pair 6 - 7 -> 0.7440073490142822
# Pair 7 - 15 -> 0.7438551187515259
# Pair 0 - 9 -> 0.7429563999176025
# Pair 2 - 4 -> 0.7422202229499817
# Pair 7 - 8 -> 0.7416990399360657
# Pair 9 - 10 -> 0.7408793568611145
# Pair 2 - 13 -> 0.7377614974975586
# Pair 5 - 15 -> 0.737155556678772
# Pair 5 - 13 -> 0.7358524799346924
# Pair 2 - 10 -> 0.7353811264038086
# Pair 4 - 14 -> 0.7344517707824707
# Pair 14 - 16 -> 0.7331321835517883
# Pair 4 - 5 -> 0.732634961605072
# Pair 13 - 14 -> 0.7325369715690613
# Pair 3 - 12 -> 0.730880856513977
# Pair 12 - 18 -> 0.7305917739868164
# Pair 3 - 5 -> 0.729383111000061
# Pair 1 - 10 -> 0.7289957404136658
# Pair 0 - 6 -> 0.7281906604766846
# Pair 1 - 6 -> 0.7279592752456665
# Pair 5 - 19 -> 0.7276768684387207
# Pair 12 - 19 -> 0.7264538407325745
# Pair 3 - 4 -> 0.7259223461151123
# Pair 2 - 18 -> 0.7258722186088562
# Pair 3 - 9 -> 0.7256922721862793
# Pair 4 - 7 -> 0.7249622941017151
# Pair 4 - 19 -> 0.7206371426582336
# Pair 0 - 10 -> 0.7205114960670471
# Pair 4 - 16 -> 0.7203958034515381
# Pair 2 - 9 -> 0.7200344204902649
# Pair 0 - 14 -> 0.7196627855300903
# Pair 2 - 8 -> 0.7184263467788696
# Pair 7 - 9 -> 0.7158384323120117
# Pair 7 - 13 -> 0.7150970697402954
# Pair 1 - 18 -> 0.7132222652435303
# Pair 0 - 2 -> 0.7105499505996704
# Pair 4 - 17 -> 0.709168016910553
# Pair 5 - 9 -> 0.7088889479637146
# Pair 1 - 5 -> 0.7050954103469849
# Pair 8 - 14 -> 0.7050096988677979
# Pair 5 - 8 -> 0.7049834728240967
# Pair 2 - 19 -> 0.7047616243362427
# Pair 1 - 2 -> 0.7042133808135986
# Pair 5 - 7 -> 0.703955352306366
# Pair 1 - 7 -> 0.703698456287384
# Pair 5 - 17 -> 0.7025998830795288
# Pair 5 - 10 -> 0.7024469375610352
# Pair 2 - 17 -> 0.7014573812484741
# Pair 2 - 16 -> 0.7008260488510132
# Pair 12 - 17 -> 0.6987779140472412
# Pair 1 - 16 -> 0.6977246999740601
# Pair 2 - 3 -> 0.6967881917953491
# Pair 0 - 5 -> 0.6926144957542419
# Pair 1 - 9 -> 0.6868273019790649
# Pair 7 - 12 -> 0.6821939945220947
# Pair 2 - 5 -> 0.6810698509216309
# Pair 5 - 14 -> 0.6796634197235107
# Pair 14 - 18 -> 0.6749277114868164
# Pair 10 - 14 -> 0.6741077303886414
# Pair 2 - 14 -> 0.6724417209625244
# Pair 2 - 7 -> 0.670159101486206
# Pair 1 - 14 -> 0.6694698333740234
# Pair 9 - 17 -> 0.6682332158088684
# Pair 3 - 14 -> 0.640036404132843
# Pair 14 - 19 -> 0.6331504583358765
# Pair 14 - 17 -> 0.6110479831695557
# Pair 7 - 14 -> 0.6044403314590454

# %%
print("Text #3:")
print(data.text[3])
print()
print("Text #17:")
print(data.text[17])
# Out:
# Text #3:
# Компания Samsung готовит ещё один очень доступный смартфон. Galaxy F13 уже засветился в Geekbench, что позволяет нам заодно узнать его основные параметры. В частности, сердцем новинки послужит SoC Exynos 850 — самая простая и бюджетная однокристальная система Samsung среди актуальных. Напомним, в её конфигурацию входят восемь ядер Cortex-A55 с частотой 2 ГГц и GPU Mali-G52 MP1. В бенчмарке платформа набирает 157 и 587 баллов в однопоточном и многопоточном режимах соответственно. При этом у тестового аппарата было 4 ГБ ОЗУ. Для сравнения, Galaxy F12 основан на той же платформе и имеет те же 4 ГБ ОЗУ. То есть с точки зрения производительности разницы не будет вообще никакой. Что изменится, неясно. Если слухи верны, и Galaxy F13 будет копией Galaxy A13, то экран увеличится до 6,6 дюйма, а ёмкость аккумулятора снизится до 5000 мА•ч.
#
# Text #17:
# Компания Lenovo готовится пополнить ассортимент смартфонов Motorola моделью Moto G62. Когда случится официальная премьера — данных нет, но источник уже опубликовал качественный рендер смартфона и перечень предполагаемых характеристик. С аппаратной точки зрения Moto G62 станет конкурентом Redmi Note 11 Pro 5G: новинке приписана та же SoC Snapdragon 695 5G. Ожидается, что Moto G62 также получит экран разрешением Full HD+, 6–8 ГБ ОЗУ и 64–128 ГБ флеш-памяти, тройную камеру с основным датчиком разрешением 50 Мп. Ёмкость аккумулятора составит 6000 мА·ч — на 1000 мА·ч больше, чем у модели Redmi. Мощность зарядки составит 33 Вт, а в качестве ОС выступит Android 12. Будет у Moto G62 и сканер отпечатков пальцев — он разместится на боковой грани.

# %%
syntatic_text = "Samsung готовит ещё один очень бюджетный смартфон. Galaxy F13 уже засветился в Geekbench, что" +\
"позволяет нам заодно узнать его основные параметры. "       +\
"При тестах платформа набирает 157 и 587 баллов в однопоточном и многопоточном режимах соответственно. При этом у " +\
"этого тестового аппарата было 4 ГБ оперативной памяти. Например Galaxy F12 "        +\
"основан на той же платформе и имеет тот же объём памяти. То есть с точки зрения производительности разницы не будет "        +\
"вообще никакой. Если теория подтвердится и Galaxy F13 будет копией Galaxy A13, то экран увеличится, а ёмкость аккумулятора снизится."

# %%
syntatic_text
# Out:
# 'Samsung готовит ещё один очень бюджетный смартфон. Galaxy F13 уже засветился в Geekbench, чтопозволяет нам заодно узнать его основные параметры. При тестах платформа набирает 157 и 587 баллов в однопоточном и многопоточном режимах соответственно. При этом у этого тестового аппарата было 4 ГБ оперативной памяти. Например Galaxy F12 основан на той же платформе и имеет тот же объём памяти. То есть с точки зрения производительности разницы не будет вообще никакой. Если теория подтвердится и Galaxy F13 будет копией Galaxy A13, то экран увеличится, а ёмкость аккумулятора снизится.'

# %%
syntatic_text_tokens = {'input_ids': 0, 'attention_mask': 0}

new_tokens = tokenizer.encode_plus(syntatic_text, max_length=512,
                                       truncation=True, padding='max_length',
                                       return_tensors='pt')

syntatic_text_tokens['input_ids'] = new_tokens['input_ids'][0].reshape(1, -1)
syntatic_text_tokens['attention_mask'] = new_tokens['attention_mask'][0].reshape(1, -1)

# %%
# %%time
syntatic_text_output = model(**syntatic_text_tokens)
# Out:
# Wall time: 4.7 s

# %%
syntatic_text_embd = syntatic_text_output.last_hidden_state

# %%
syn_attention_mask = syntatic_text_tokens['attention_mask']
# Reshaping attenion mask
syn_mask = syn_attention_mask.unsqueeze(-1).expand(syntatic_text_embd.size()).float()
# Applying attention mask
syn_masked_embeddings = syntatic_text_embd * syn_mask
# Getting average vector
syn_summed = torch.sum(syn_masked_embeddings, 1)

syn_summed_mask = torch.clamp(syn_mask.sum(1), min=1e-9)

syn_text_vector = syn_summed / syn_summed_mask

# %%
syn_cosine_similarities_dct = dict()
text_vectors_with_synt = torch.vstack([text_vectors, syn_text_vector])

for i in range(text_vectors_with_synt.shape[0]):
    for j in range(i + 1, text_vectors_with_synt.shape[0]):
        first_vector = text_vectors_with_synt[i].detach().numpy().reshape(1, -1)
        second_vector = text_vectors_with_synt[j].detach().numpy().reshape(1, -1)
        syn_cosine_similarities_dct[f'{i} - {j}'] = {
            "Cosine measure": cosine_similarity(first_vector, second_vector)[0][0],
            "Manhattan distance": manhattan_distances(first_vector, second_vector)[0][0],
            "Euclidian distance": euclidean_distances(first_vector, second_vector)[0][0],
        }

# %%
for pair, similarity in sorted(syn_cosine_similarities_dct.items(), key=lambda x: x[1]['Cosine measure'], reverse=True):
    print(f"Pair {pair} -> {similarity}")
# Out:
# Pair 3 - 17 -> {'Cosine measure': 0.9160645, 'Manhattan distance': 80.24904120840074, 'Euclidian distance': 3.6523664}
# Pair 3 - 19 -> {'Cosine measure': 0.9086665, 'Manhattan distance': 84.65269611473195, 'Euclidian distance': 3.8062818}
# Pair 3 - 20 -> {'Cosine measure': 0.90118915, 'Manhattan distance': 93.22176944675448, 'Euclidian distance': 4.1853266}
# Pair 3 - 18 -> {'Cosine measure': 0.88238597, 'Manhattan distance': 97.29390385841543, 'Euclidian distance': 4.4848604}
# Pair 17 - 19 -> {'Cosine measure': 0.8762884, 'Manhattan distance': 99.04203205138037, 'Euclidian distance': 4.504569}
# Pair 8 - 13 -> {'Cosine measure': 0.8704393, 'Manhattan distance': 107.3117418197362, 'Euclidian distance': 4.8723288}
# Pair 3 - 7 -> {'Cosine measure': 0.8688899, 'Manhattan distance': 100.10682574861858, 'Euclidian distance': 4.5001836}
# Pair 18 - 19 -> {'Cosine measure': 0.8605534, 'Manhattan distance': 108.21965754123812, 'Euclidian distance': 4.9223475}
# Pair 11 - 15 -> {'Cosine measure': 0.85895914, 'Manhattan distance': 109.77742405605386, 'Euclidian distance': 5.0871243}
# Pair 0 - 20 -> {'Cosine measure': 0.85168517, 'Manhattan distance': 116.02721564291278, 'Euclidian distance': 5.2811213}
# Pair 11 - 13 -> {'Cosine measure': 0.8478222, 'Manhattan distance': 116.89586487645283, 'Euclidian distance': 5.3258324}
# Pair 1 - 13 -> {'Cosine measure': 0.84680635, 'Manhattan distance': 117.65382672045962, 'Euclidian distance': 5.404973}
# Pair 0 - 3 -> {'Cosine measure': 0.8467146, 'Manhattan distance': 114.2816450655373, 'Euclidian distance': 5.197454}
# Pair 7 - 17 -> {'Cosine measure': 0.8438275, 'Manhattan distance': 110.94136235068436, 'Euclidian distance': 5.016777}
# Pair 13 - 15 -> {'Cosine measure': 0.8434358, 'Manhattan distance': 118.32263642174075, 'Euclidian distance': 5.3981256}
# Pair 0 - 17 -> {'Cosine measure': 0.8427706, 'Manhattan distance': 118.82256407305249, 'Euclidian distance': 5.3093295}
# Pair 4 - 15 -> {'Cosine measure': 0.8415981, 'Manhattan distance': 118.57287565109436, 'Euclidian distance': 5.4538035}
# Pair 0 - 15 -> {'Cosine measure': 0.8410002, 'Manhattan distance': 120.56146298602107, 'Euclidian distance': 5.4456415}
# Pair 10 - 18 -> {'Cosine measure': 0.8375212, 'Manhattan distance': 118.25140298120095, 'Euclidian distance': 5.4170427}
# Pair 4 - 11 -> {'Cosine measure': 0.8359226, 'Manhattan distance': 121.5045183749753, 'Euclidian distance': 5.554276}
# Pair 7 - 18 -> {'Cosine measure': 0.8346828, 'Manhattan distance': 118.23664964339696, 'Euclidian distance': 5.323348}
# Pair 16 - 18 -> {'Cosine measure': 0.8337271, 'Manhattan distance': 120.27296253888926, 'Euclidian distance': 5.4394994}
# Pair 17 - 18 -> {'Cosine measure': 0.8276875, 'Manhattan distance': 121.94993775666808, 'Euclidian distance': 5.468552}
# Pair 1 - 8 -> {'Cosine measure': 0.827633, 'Manhattan distance': 124.11632408144942, 'Euclidian distance': 5.649889}
# Pair 6 - 18 -> {'Cosine measure': 0.82654107, 'Manhattan distance': 121.63397388276644, 'Euclidian distance': 5.5250497}
# Pair 6 - 16 -> {'Cosine measure': 0.82515603, 'Manhattan distance': 120.94771883414069, 'Euclidian distance': 5.4914193}
# Pair 0 - 19 -> {'Cosine measure': 0.82423365, 'Manhattan distance': 124.70351758050674, 'Euclidian distance': 5.6076336}
# Pair 3 - 16 -> {'Cosine measure': 0.8226327, 'Manhattan distance': 120.51887703128159, 'Euclidian distance': 5.4038506}
# Pair 8 - 19 -> {'Cosine measure': 0.8197688, 'Manhattan distance': 121.7281878842332, 'Euclidian distance': 5.544107}
# Pair 16 - 19 -> {'Cosine measure': 0.8197058, 'Manhattan distance': 121.30929226393346, 'Euclidian distance': 5.530537}
# Pair 0 - 11 -> {'Cosine measure': 0.8193777, 'Manhattan distance': 126.35492918780074, 'Euclidian distance': 5.8079753}
# Pair 7 - 19 -> {'Cosine measure': 0.81846035, 'Manhattan distance': 119.34385951513832, 'Euclidian distance': 5.4063573}
# Pair 19 - 20 -> {'Cosine measure': 0.81839955, 'Manhattan distance': 125.52730704257556, 'Euclidian distance': 5.666868}
# Pair 12 - 16 -> {'Cosine measure': 0.81661844, 'Manhattan distance': 131.9147518788377, 'Euclidian distance': 5.895512}
# Pair 9 - 15 -> {'Cosine measure': 0.8146833, 'Manhattan distance': 127.51434261596296, 'Euclidian distance': 5.8071775}
# Pair 6 - 12 -> {'Cosine measure': 0.8138136, 'Manhattan distance': 133.98931898525916, 'Euclidian distance': 5.91696}
# Pair 9 - 11 -> {'Cosine measure': 0.8136051, 'Manhattan distance': 126.82870967927738, 'Euclidian distance': 5.8288302}
# Pair 12 - 15 -> {'Cosine measure': 0.81312954, 'Manhattan distance': 133.2619244508387, 'Euclidian distance': 6.0005345}
# Pair 10 - 19 -> {'Cosine measure': 0.8122871, 'Manhattan distance': 124.79917569675308, 'Euclidian distance': 5.696913}
# Pair 1 - 11 -> {'Cosine measure': 0.81192935, 'Manhattan distance': 129.0179358459718, 'Euclidian distance': 5.9516454}
# Pair 3 - 10 -> {'Cosine measure': 0.81184655, 'Manhattan distance': 123.8988325442624, 'Euclidian distance': 5.6263094}
# Pair 5 - 16 -> {'Cosine measure': 0.8114737, 'Manhattan distance': 127.38752877539082, 'Euclidian distance': 5.74159}
# Pair 0 - 13 -> {'Cosine measure': 0.8103945, 'Manhattan distance': 129.7594615642447, 'Euclidian distance': 5.9891276}
# Pair 5 - 6 -> {'Cosine measure': 0.8088178, 'Manhattan distance': 125.58562523452565, 'Euclidian distance': 5.7463326}
# Pair 15 - 16 -> {'Cosine measure': 0.808272, 'Manhattan distance': 129.34450400008063, 'Euclidian distance': 5.860301}
# Pair 13 - 19 -> {'Cosine measure': 0.80544865, 'Manhattan distance': 129.9616933233192, 'Euclidian distance': 5.8877983}
# Pair 6 - 10 -> {'Cosine measure': 0.8052173, 'Manhattan distance': 127.73396813773434, 'Euclidian distance': 5.8466864}
# Pair 8 - 15 -> {'Cosine measure': 0.8040463, 'Manhattan distance': 130.2707799490454, 'Euclidian distance': 5.9360924}
# Pair 8 - 17 -> {'Cosine measure': 0.80172074, 'Manhattan distance': 128.4423155576369, 'Euclidian distance': 5.815777}
# Pair 17 - 20 -> {'Cosine measure': 0.8004163, 'Manhattan distance': 132.3303801486909, 'Euclidian distance': 5.9392}
# Pair 0 - 1 -> {'Cosine measure': 0.80008346, 'Manhattan distance': 136.04243917120039, 'Euclidian distance': 6.179863}
# Pair 15 - 18 -> {'Cosine measure': 0.7995167, 'Manhattan distance': 134.04387257256894, 'Euclidian distance': 6.0422764}
# Pair 4 - 6 -> {'Cosine measure': 0.7984554, 'Manhattan distance': 130.69076299393782, 'Euclidian distance': 6.061324}
# Pair 12 - 13 -> {'Cosine measure': 0.79837865, 'Manhattan distance': 136.32811338303145, 'Euclidian distance': 6.270127}
# Pair 11 - 18 -> {'Cosine measure': 0.79648113, 'Manhattan distance': 133.55126083421055, 'Euclidian distance': 6.092814}
# Pair 0 - 18 -> {'Cosine measure': 0.794598, 'Manhattan distance': 136.6747094715247, 'Euclidian distance': 6.171959}
# Pair 11 - 19 -> {'Cosine measure': 0.7940629, 'Manhattan distance': 131.4806422615511, 'Euclidian distance': 6.002126}
# Pair 3 - 15 -> {'Cosine measure': 0.79401565, 'Manhattan distance': 130.846546058674, 'Euclidian distance': 5.9165187}
# Pair 4 - 13 -> {'Cosine measure': 0.7938534, 'Manhattan distance': 134.67813216074137, 'Euclidian distance': 6.2641215}
# Pair 0 - 8 -> {'Cosine measure': 0.79361355, 'Manhattan distance': 138.49659017728118, 'Euclidian distance': 6.151105}
# Pair 8 - 11 -> {'Cosine measure': 0.79207766, 'Manhattan distance': 133.94681920499715, 'Euclidian distance': 6.1198187}
# Pair 2 - 15 -> {'Cosine measure': 0.7901488, 'Manhattan distance': 144.3901559645892, 'Euclidian distance': 6.501728}
# Pair 18 - 20 -> {'Cosine measure': 0.78886664, 'Manhattan distance': 136.0906868648599, 'Euclidian distance': 6.2297053}
# Pair 15 - 19 -> {'Cosine measure': 0.7887246, 'Manhattan distance': 134.80725786114635, 'Euclidian distance': 6.0727477}
# Pair 6 - 11 -> {'Cosine measure': 0.7882837, 'Manhattan distance': 134.66732664313167, 'Euclidian distance': 6.1296306}
# Pair 3 - 8 -> {'Cosine measure': 0.78782886, 'Manhattan distance': 130.52129047783092, 'Euclidian distance': 5.9205837}
# Pair 6 - 15 -> {'Cosine measure': 0.7877596, 'Manhattan distance': 134.472288045421, 'Euclidian distance': 6.1314883}
# Pair 6 - 8 -> {'Cosine measure': 0.7870616, 'Manhattan distance': 132.53416549948452, 'Euclidian distance': 6.0742946}
# Pair 16 - 17 -> {'Cosine measure': 0.7868943, 'Manhattan distance': 132.30283441480424, 'Euclidian distance': 6.0132565}
# Pair 3 - 11 -> {'Cosine measure': 0.78583765, 'Manhattan distance': 132.38777477039548, 'Euclidian distance': 6.037105}
# Pair 7 - 11 -> {'Cosine measure': 0.78439784, 'Manhattan distance': 135.68407537287567, 'Euclidian distance': 6.100272}
# Pair 12 - 14 -> {'Cosine measure': 0.78307855, 'Manhattan distance': 147.51053086860338, 'Euclidian distance': 6.7444386}
# Pair 1 - 19 -> {'Cosine measure': 0.7829298, 'Manhattan distance': 135.4738116143999, 'Euclidian distance': 6.255371}
# Pair 4 - 9 -> {'Cosine measure': 0.78061736, 'Manhattan distance': 142.80948464936228, 'Euclidian distance': 6.3976784}
# Pair 1 - 15 -> {'Cosine measure': 0.7805183, 'Manhattan distance': 141.57781923242146, 'Euclidian distance': 6.4243035}
# Pair 14 - 15 -> {'Cosine measure': 0.77844876, 'Manhattan distance': 145.87146767767263, 'Euclidian distance': 6.7067323}
# Pair 6 - 9 -> {'Cosine measure': 0.777437, 'Manhattan distance': 137.30817727631074, 'Euclidian distance': 6.2539015}
# Pair 3 - 6 -> {'Cosine measure': 0.7759658, 'Manhattan distance': 133.63408137766237, 'Euclidian distance': 6.013081}
# Pair 9 - 18 -> {'Cosine measure': 0.7752417, 'Manhattan distance': 140.42327334018773, 'Euclidian distance': 6.3756647}
# Pair 10 - 16 -> {'Cosine measure': 0.7749227, 'Manhattan distance': 139.692585036144, 'Euclidian distance': 6.320583}
# Pair 15 - 20 -> {'Cosine measure': 0.77429384, 'Manhattan distance': 141.73459400070715, 'Euclidian distance': 6.4594793}
# Pair 0 - 7 -> {'Cosine measure': 0.774052, 'Manhattan distance': 138.96948625554796, 'Euclidian distance': 6.3092256}
# Pair 5 - 12 -> {'Cosine measure': 0.77315676, 'Manhattan distance': 143.60253338492475, 'Euclidian distance': 6.5520864}
# Pair 15 - 17 -> {'Cosine measure': 0.77246714, 'Manhattan distance': 138.76641226850916, 'Euclidian distance': 6.302086}
# Pair 13 - 18 -> {'Cosine measure': 0.7717453, 'Manhattan distance': 142.6467902540462, 'Euclidian distance': 6.4990177}
# Pair 11 - 12 -> {'Cosine measure': 0.7717026, 'Manhattan distance': 145.64163292467128, 'Euclidian distance': 6.633358}
# Pair 7 - 10 -> {'Cosine measure': 0.77155626, 'Manhattan distance': 136.92936353883124, 'Euclidian distance': 6.236949}
# Pair 6 - 19 -> {'Cosine measure': 0.77032864, 'Manhattan distance': 136.8453077465383, 'Euclidian distance': 6.1958494}
# Pair 9 - 13 -> {'Cosine measure': 0.77021956, 'Manhattan distance': 145.35940709974966, 'Euclidian distance': 6.5184937}
# Pair 0 - 4 -> {'Cosine measure': 0.7697174, 'Manhattan distance': 145.45374759257538, 'Euclidian distance': 6.6267595}
# Pair 8 - 10 -> {'Cosine measure': 0.7692309, 'Manhattan distance': 141.7586039017915, 'Euclidian distance': 6.413289}
# Pair 1 - 3 -> {'Cosine measure': 0.7691952, 'Manhattan distance': 138.59907179242873, 'Euclidian distance': 6.3696704}
# Pair 1 - 17 -> {'Cosine measure': 0.76877797, 'Manhattan distance': 138.54858879226958, 'Euclidian distance': 6.4546356}
# Pair 7 - 20 -> {'Cosine measure': 0.7684816, 'Manhattan distance': 141.82842008251464, 'Euclidian distance': 6.349622}
# Pair 0 - 16 -> {'Cosine measure': 0.76839304, 'Manhattan distance': 145.46388427518832, 'Euclidian distance': 6.5029764}
# Pair 8 - 18 -> {'Cosine measure': 0.76702034, 'Manhattan distance': 143.05803651582391, 'Euclidian distance': 6.451233}
# Pair 3 - 13 -> {'Cosine measure': 0.76689327, 'Manhattan distance': 141.2156044293224, 'Euclidian distance': 6.3545976}
# Pair 10 - 11 -> {'Cosine measure': 0.7662246, 'Manhattan distance': 143.89677694786224, 'Euclidian distance': 6.523203}
# Pair 10 - 15 -> {'Cosine measure': 0.7654335, 'Manhattan distance': 142.45486733870348, 'Euclidian distance': 6.5288754}
# Pair 13 - 16 -> {'Cosine measure': 0.76518166, 'Manhattan distance': 144.79756961741077, 'Euclidian distance': 6.540436}
# Pair 4 - 10 -> {'Cosine measure': 0.7648625, 'Manhattan distance': 145.3009311821952, 'Euclidian distance': 6.6189036}
# Pair 11 - 16 -> {'Cosine measure': 0.7641904, 'Manhattan distance': 141.53952417128312, 'Euclidian distance': 6.5039334}
# Pair 6 - 14 -> {'Cosine measure': 0.7636614, 'Manhattan distance': 150.63532071496593, 'Euclidian distance': 6.8514605}
# Pair 1 - 4 -> {'Cosine measure': 0.76316196, 'Manhattan distance': 147.40875482492265, 'Euclidian distance': 6.7460957}
# Pair 11 - 17 -> {'Cosine measure': 0.7631251, 'Manhattan distance': 137.00718788002268, 'Euclidian distance': 6.43559}
# Pair 6 - 13 -> {'Cosine measure': 0.76311433, 'Manhattan distance': 144.93322317313869, 'Euclidian distance': 6.5349956}
# Pair 0 - 12 -> {'Cosine measure': 0.7610966, 'Manhattan distance': 150.80082796828356, 'Euclidian distance': 6.8298044}
# Pair 5 - 11 -> {'Cosine measure': 0.7606088, 'Manhattan distance': 143.6507152711274, 'Euclidian distance': 6.5570707}
# Pair 10 - 13 -> {'Cosine measure': 0.7601795, 'Manhattan distance': 147.91673057546723, 'Euclidian distance': 6.6549797}
# Pair 9 - 14 -> {'Cosine measure': 0.7598093, 'Manhattan distance': 151.80206820715102, 'Euclidian distance': 6.963714}
# Pair 8 - 16 -> {'Cosine measure': 0.75979865, 'Manhattan distance': 142.2017405043589, 'Euclidian distance': 6.4909196}
# Pair 13 - 17 -> {'Cosine measure': 0.75919294, 'Manhattan distance': 143.6707591781451, 'Euclidian distance': 6.5440526}
# Pair 4 - 12 -> {'Cosine measure': 0.75624466, 'Manhattan distance': 151.87441327312263, 'Euclidian distance': 6.9172983}
# Pair 2 - 12 -> {'Cosine measure': 0.7554194, 'Manhattan distance': 156.61176408847678, 'Euclidian distance': 7.13397}
# Pair 9 - 12 -> {'Cosine measure': 0.75520587, 'Manhattan distance': 150.47302254362148, 'Euclidian distance': 6.8447614}
# Pair 8 - 12 -> {'Cosine measure': 0.75394624, 'Manhattan distance': 150.27466295725026, 'Euclidian distance': 6.8288794}
# Pair 6 - 17 -> {'Cosine measure': 0.75363225, 'Manhattan distance': 142.56456188540324, 'Euclidian distance': 6.419}
# Pair 9 - 19 -> {'Cosine measure': 0.753584, 'Manhattan distance': 143.20622555220325, 'Euclidian distance': 6.528067}
# Pair 8 - 9 -> {'Cosine measure': 0.75339186, 'Manhattan distance': 145.2684440403973, 'Euclidian distance': 6.6345773}
# Pair 11 - 14 -> {'Cosine measure': 0.7509377, 'Manhattan distance': 155.7540139204939, 'Euclidian distance': 7.108188}
# Pair 5 - 18 -> {'Cosine measure': 0.7508832, 'Manhattan distance': 147.36644996795803, 'Euclidian distance': 6.661243}
# Pair 9 - 16 -> {'Cosine measure': 0.7505058, 'Manhattan distance': 145.8197390523128, 'Euclidian distance': 6.65942}
# Pair 10 - 12 -> {'Cosine measure': 0.7501255, 'Manhattan distance': 154.8195032083022, 'Euclidian distance': 6.9111814}
# Pair 2 - 11 -> {'Cosine measure': 0.74928296, 'Manhattan distance': 158.27440862215008, 'Euclidian distance': 7.101827}
# Pair 4 - 18 -> {'Cosine measure': 0.74787307, 'Manhattan distance': 152.8084579811548, 'Euclidian distance': 6.8598714}
# Pair 2 - 6 -> {'Cosine measure': 0.74769497, 'Manhattan distance': 153.36847806241713, 'Euclidian distance': 7.039653}
# Pair 4 - 8 -> {'Cosine measure': 0.74667436, 'Manhattan distance': 149.27875390478584, 'Euclidian distance': 6.836412}
# Pair 1 - 12 -> {'Cosine measure': 0.7460956, 'Manhattan distance': 155.60982495147618, 'Euclidian distance': 7.065189}
# Pair 7 - 16 -> {'Cosine measure': 0.74569666, 'Manhattan distance': 145.94813243801764, 'Euclidian distance': 6.5139675}
# Pair 10 - 17 -> {'Cosine measure': 0.7452862, 'Manhattan distance': 145.71724623034243, 'Euclidian distance': 6.632865}
# Pair 6 - 7 -> {'Cosine measure': 0.74400735, 'Manhattan distance': 142.3317943237489, 'Euclidian distance': 6.486403}
# Pair 7 - 15 -> {'Cosine measure': 0.7438551, 'Manhattan distance': 146.55614930044976, 'Euclidian distance': 6.635404}
# Pair 0 - 9 -> {'Cosine measure': 0.7429564, 'Manhattan distance': 150.21496038985788, 'Euclidian distance': 6.901149}
# Pair 2 - 4 -> {'Cosine measure': 0.7422202, 'Manhattan distance': 158.38015003540204, 'Euclidian distance': 7.257351}
# Pair 11 - 20 -> {'Cosine measure': 0.742082, 'Manhattan distance': 152.31085572607117, 'Euclidian distance': 6.910252}
# Pair 7 - 8 -> {'Cosine measure': 0.74169904, 'Manhattan distance': 142.57028798344254, 'Euclidian distance': 6.5821967}
# Pair 9 - 10 -> {'Cosine measure': 0.74087936, 'Manhattan distance': 150.40710097231204, 'Euclidian distance': 6.838356}
# Pair 2 - 13 -> {'Cosine measure': 0.7377615, 'Manhattan distance': 163.21026783037814, 'Euclidian distance': 7.2972097}
# Pair 5 - 15 -> {'Cosine measure': 0.73715556, 'Manhattan distance': 150.06855869133142, 'Euclidian distance': 6.864488}
# Pair 5 - 13 -> {'Cosine measure': 0.7358525, 'Manhattan distance': 153.33413260953967, 'Euclidian distance': 6.939666}
# Pair 2 - 10 -> {'Cosine measure': 0.7353811, 'Manhattan distance': 157.084613141953, 'Euclidian distance': 7.269202}
# Pair 10 - 20 -> {'Cosine measure': 0.7345806, 'Manhattan distance': 153.31482896165107, 'Euclidian distance': 6.9773874}
# Pair 4 - 14 -> {'Cosine measure': 0.7344518, 'Manhattan distance': 160.16302979795728, 'Euclidian distance': 7.3936753}
# Pair 8 - 20 -> {'Cosine measure': 0.73316544, 'Manhattan distance': 154.45254259095236, 'Euclidian distance': 6.95977}
# Pair 14 - 16 -> {'Cosine measure': 0.7331322, 'Manhattan distance': 162.0516793604038, 'Euclidian distance': 7.2944455}
# Pair 4 - 5 -> {'Cosine measure': 0.73263496, 'Manhattan distance': 154.72009715711465, 'Euclidian distance': 7.0136657}
# Pair 13 - 14 -> {'Cosine measure': 0.732537, 'Manhattan distance': 161.8680318565457, 'Euclidian distance': 7.398077}
# Pair 13 - 20 -> {'Cosine measure': 0.73159266, 'Manhattan distance': 153.00557844742434, 'Euclidian distance': 7.0971465}
# Pair 3 - 12 -> {'Cosine measure': 0.73088086, 'Manhattan distance': 155.3462646689586, 'Euclidian distance': 6.96662}
# Pair 12 - 18 -> {'Cosine measure': 0.7305918, 'Manhattan distance': 156.85667217266746, 'Euclidian distance': 7.181002}
# Pair 3 - 5 -> {'Cosine measure': 0.7293831, 'Manhattan distance': 143.15866376030317, 'Euclidian distance': 6.6629972}
# Pair 1 - 10 -> {'Cosine measure': 0.72899574, 'Manhattan distance': 155.74041275447235, 'Euclidian distance': 7.111575}
# Pair 16 - 20 -> {'Cosine measure': 0.7287791, 'Manhattan distance': 153.63737697976467, 'Euclidian distance': 7.002908}
# Pair 0 - 6 -> {'Cosine measure': 0.72819066, 'Manhattan distance': 155.51386743609328, 'Euclidian distance': 7.0055914}
# Pair 1 - 6 -> {'Cosine measure': 0.7279593, 'Manhattan distance': 152.87884755406412, 'Euclidian distance': 7.0413013}
# Pair 5 - 19 -> {'Cosine measure': 0.72767687, 'Manhattan distance': 149.5256694683194, 'Euclidian distance': 6.79901}
# Pair 12 - 19 -> {'Cosine measure': 0.72645384, 'Manhattan distance': 157.92836192178947, 'Euclidian distance': 7.106728}
# Pair 3 - 4 -> {'Cosine measure': 0.72592235, 'Manhattan distance': 152.29492630746972, 'Euclidian distance': 6.9152837}
# Pair 2 - 18 -> {'Cosine measure': 0.7258722, 'Manhattan distance': 161.49227308793343, 'Euclidian distance': 7.402269}
# Pair 3 - 9 -> {'Cosine measure': 0.7256923, 'Manhattan distance': 149.63705483886588, 'Euclidian distance': 6.777155}
# Pair 9 - 20 -> {'Cosine measure': 0.7255085, 'Manhattan distance': 156.30892082347418, 'Euclidian distance': 7.100274}
# Pair 4 - 7 -> {'Cosine measure': 0.7249623, 'Manhattan distance': 156.03379740723176, 'Euclidian distance': 6.9775953}
# Pair 4 - 19 -> {'Cosine measure': 0.72063714, 'Manhattan distance': 155.22512155659206, 'Euclidian distance': 7.077074}
# Pair 0 - 10 -> {'Cosine measure': 0.7205115, 'Manhattan distance': 160.13818733676453, 'Euclidian distance': 7.1911955}
# Pair 4 - 16 -> {'Cosine measure': 0.7203958, 'Manhattan distance': 157.03545521556225, 'Euclidian distance': 7.167718}
# Pair 2 - 9 -> {'Cosine measure': 0.7200344, 'Manhattan distance': 166.8875858139363, 'Euclidian distance': 7.4777083}
# Pair 0 - 14 -> {'Cosine measure': 0.7196628, 'Manhattan distance': 166.31082043604692, 'Euclidian distance': 7.5778465}
# Pair 2 - 8 -> {'Cosine measure': 0.71842635, 'Manhattan distance': 161.84795476139698, 'Euclidian distance': 7.466714}
# Pair 7 - 9 -> {'Cosine measure': 0.71583843, 'Manhattan distance': 152.25197441477212, 'Euclidian distance': 6.955648}
# Pair 7 - 13 -> {'Cosine measure': 0.71509707, 'Manhattan distance': 155.4935312800808, 'Euclidian distance': 7.0624685}
# Pair 1 - 20 -> {'Cosine measure': 0.71440506, 'Manhattan distance': 162.32631755867624, 'Euclidian distance': 7.3574553}
# Pair 1 - 18 -> {'Cosine measure': 0.71322227, 'Manhattan distance': 158.3135945852555, 'Euclidian distance': 7.322209}
# Pair 0 - 2 -> {'Cosine measure': 0.71054995, 'Manhattan distance': 169.97907576159923, 'Euclidian distance': 7.669328}
# Pair 4 - 17 -> {'Cosine measure': 0.709168, 'Manhattan distance': 157.71563622026588, 'Euclidian distance': 7.2211623}
# Pair 5 - 9 -> {'Cosine measure': 0.70888895, 'Manhattan distance': 158.49481675584684, 'Euclidian distance': 7.1977377}
# Pair 1 - 5 -> {'Cosine measure': 0.7050954, 'Manhattan distance': 162.7819412012177, 'Euclidian distance': 7.371933}
# Pair 8 - 14 -> {'Cosine measure': 0.7050097, 'Manhattan distance': 167.14877397827513, 'Euclidian distance': 7.6718903}
# Pair 5 - 8 -> {'Cosine measure': 0.7049835, 'Manhattan distance': 159.84637969474716, 'Euclidian distance': 7.198332}
# Pair 2 - 19 -> {'Cosine measure': 0.7047616, 'Manhattan distance': 165.32048010265862, 'Euclidian distance': 7.5589514}
# Pair 1 - 2 -> {'Cosine measure': 0.7042134, 'Manhattan distance': 170.76910557592055, 'Euclidian distance': 7.776216}
# Pair 5 - 7 -> {'Cosine measure': 0.70395535, 'Manhattan distance': 153.8231472959742, 'Euclidian distance': 7.0314}
# Pair 1 - 7 -> {'Cosine measure': 0.70369846, 'Manhattan distance': 158.19958186495933, 'Euclidian distance': 7.24604}
# Pair 5 - 17 -> {'Cosine measure': 0.7025999, 'Manhattan distance': 153.45219400894712, 'Euclidian distance': 7.1067586}
# Pair 5 - 10 -> {'Cosine measure': 0.70244694, 'Manhattan distance': 161.73610848010867, 'Euclidian distance': 7.2715154}
# Pair 2 - 17 -> {'Cosine measure': 0.7014574, 'Manhattan distance': 166.0525155006908, 'Euclidian distance': 7.6013374}
# Pair 2 - 16 -> {'Cosine measure': 0.70082605, 'Manhattan distance': 169.27510812970286, 'Euclidian distance': 7.6813188}
# Pair 12 - 17 -> {'Cosine measure': 0.6987779, 'Manhattan distance': 163.2843120272446, 'Euclidian distance': 7.453073}
# Pair 1 - 16 -> {'Cosine measure': 0.6977247, 'Manhattan distance': 165.06062540654966, 'Euclidian distance': 7.4588704}
# Pair 12 - 20 -> {'Cosine measure': 0.69719094, 'Manhattan distance': 169.3525573682855, 'Euclidian distance': 7.6599855}
# Pair 2 - 3 -> {'Cosine measure': 0.6967882, 'Manhattan distance': 165.02141492032388, 'Euclidian distance': 7.575856}
# Pair 6 - 20 -> {'Cosine measure': 0.6941427, 'Manhattan distance': 164.39822900953004, 'Euclidian distance': 7.394219}
# Pair 0 - 5 -> {'Cosine measure': 0.6926145, 'Manhattan distance': 166.9694019347662, 'Euclidian distance': 7.4927535}
# Pair 2 - 20 -> {'Cosine measure': 0.69128954, 'Manhattan distance': 172.23563066197676, 'Euclidian distance': 7.8934917}
# Pair 1 - 9 -> {'Cosine measure': 0.6868273, 'Manhattan distance': 167.88758279377362, 'Euclidian distance': 7.648676}
# Pair 4 - 20 -> {'Cosine measure': 0.6831764, 'Manhattan distance': 170.37222662428394, 'Euclidian distance': 7.7422247}
# Pair 7 - 12 -> {'Cosine measure': 0.682194, 'Manhattan distance': 165.97603258909658, 'Euclidian distance': 7.603037}
# Pair 2 - 5 -> {'Cosine measure': 0.68106985, 'Manhattan distance': 174.81865488286712, 'Euclidian distance': 7.930211}
# Pair 5 - 14 -> {'Cosine measure': 0.6796634, 'Manhattan distance': 174.89494769863086, 'Euclidian distance': 7.9806156}
# Pair 14 - 18 -> {'Cosine measure': 0.6749277, 'Manhattan distance': 177.8674794433755, 'Euclidian distance': 8.084697}
# Pair 10 - 14 -> {'Cosine measure': 0.67410773, 'Manhattan distance': 175.60197880186024, 'Euclidian distance': 8.0885105}
# Pair 2 - 14 -> {'Cosine measure': 0.6724417, 'Manhattan distance': 185.20655188013916, 'Euclidian distance': 8.417105}
# Pair 2 - 7 -> {'Cosine measure': 0.6701591, 'Manhattan distance': 173.2657574827026, 'Euclidian distance': 7.934062}
# Pair 1 - 14 -> {'Cosine measure': 0.66946983, 'Manhattan distance': 177.2016037380381, 'Euclidian distance': 8.248509}
# Pair 9 - 17 -> {'Cosine measure': 0.6682332, 'Manhattan distance': 166.2691185544245, 'Euclidian distance': 7.572271}
# Pair 3 - 14 -> {'Cosine measure': 0.6400364, 'Manhattan distance': 181.21201004834438, 'Euclidian distance': 8.26046}
# Pair 14 - 19 -> {'Cosine measure': 0.63315046, 'Manhattan distance': 183.90536743872508, 'Euclidian distance': 8.437393}
# Pair 14 - 20 -> {'Cosine measure': 0.62692034, 'Manhattan distance': 187.0605420934735, 'Euclidian distance': 8.704191}
# Pair 5 - 20 -> {'Cosine measure': 0.6203911, 'Manhattan distance': 179.7367159872665, 'Euclidian distance': 8.287668}
# Pair 14 - 17 -> {'Cosine measure': 0.611048, 'Manhattan distance': 192.28811822537682, 'Euclidian distance': 8.683195}
# Pair 7 - 14 -> {'Cosine measure': 0.60444033, 'Manhattan distance': 189.6005111480481, 'Euclidian distance': 8.701293}

# %%
print("Text #3:")
print(data.text[3])
print()
print("Text #17:")
print(data.text[17])
print()
print("Syntetic text: ")
print(syntatic_text)
# Out:
# Text #3:
# Компания Samsung готовит ещё один очень доступный смартфон. Galaxy F13 уже засветился в Geekbench, что позволяет нам заодно узнать его основные параметры. В частности, сердцем новинки послужит SoC Exynos 850 — самая простая и бюджетная однокристальная система Samsung среди актуальных. Напомним, в её конфигурацию входят восемь ядер Cortex-A55 с частотой 2 ГГц и GPU Mali-G52 MP1. В бенчмарке платформа набирает 157 и 587 баллов в однопоточном и многопоточном режимах соответственно. При этом у тестового аппарата было 4 ГБ ОЗУ. Для сравнения, Galaxy F12 основан на той же платформе и имеет те же 4 ГБ ОЗУ. То есть с точки зрения производительности разницы не будет вообще никакой. Что изменится, неясно. Если слухи верны, и Galaxy F13 будет копией Galaxy A13, то экран увеличится до 6,6 дюйма, а ёмкость аккумулятора снизится до 5000 мА•ч.
#
# Text #17:
# Компания Lenovo готовится пополнить ассортимент смартфонов Motorola моделью Moto G62. Когда случится официальная премьера — данных нет, но источник уже опубликовал качественный рендер смартфона и перечень предполагаемых характеристик. С аппаратной точки зрения Moto G62 станет конкурентом Redmi Note 11 Pro 5G: новинке приписана та же SoC Snapdragon 695 5G. Ожидается, что Moto G62 также получит экран разрешением Full HD+, 6–8 ГБ ОЗУ и 64–128 ГБ флеш-памяти, тройную камеру с основным датчиком разрешением 50 Мп. Ёмкость аккумулятора составит 6000 мА·ч — на 1000 мА·ч больше, чем у модели Redmi. Мощность зарядки составит 33 Вт, а в качестве ОС выступит Android 12. Будет у Moto G62 и сканер отпечатков пальцев — он разместится на боковой грани.
#
# Syntetic text:
# Samsung готовит ещё один очень бюджетный смартфон. Galaxy F13 уже засветился в Geekbench, чтопозволяет нам заодно узнать его основные параметры. При тестах платформа набирает 157 и 587 баллов в однопоточном и многопоточном режимах соответственно. При этом у этого тестового аппарата было 4 ГБ оперативной памяти. Например Galaxy F12 основан на той же платформе и имеет тот же объём памяти. То есть с точки зрения производительности разницы не будет вообще никакой. Если теория подтвердится и Galaxy F13 будет копией Galaxy A13, то экран увеличится, а ёмкость аккумулятора снизится.

# %% [markdown]
# ## BERT pipeline
#
#     Creating one pipeline for our all code above

# %%
class RuBERT:
    def __init__(self):
        self.model = AutoModel.from_pretrained("DeepPavlov/rubert-base-cased-conversational")
        self.tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased-conversational")
    
    def get_embeddings(self, texts: list, update_idf=False):
        tokens = {'input_ids': [], 'attention_mask': []}

        for sentence in texts:
            # encode each sentence and append to dictionary
            new_tokens = self.tokenizer.encode_plus(sentence, max_length=512,
                                                    truncation=True, padding='max_length',
                                                    return_tensors='pt')
            tokens['input_ids'].append(new_tokens['input_ids'][0])
            tokens['attention_mask'].append(new_tokens['attention_mask'][0])

        # reformat list of tensors into single tensor
        tokens['input_ids'] = torch.stack(tokens['input_ids'])
        tokens['attention_mask'] = torch.stack(tokens['attention_mask'])
        # Running model
        outputs = self.model(**tokens)

        embeddings = outputs.last_hidden_state
        # Updating IDF if necessery
        if update_idf:
            # Calculating IDF score
            self.idfs_score = dict()

            for line in tokens['input_ids']:
                u_line_tokens = torch.unique(line)
                for token in u_line_tokens:
                    try:
                        self.idfs_score[token.item()] += 1
                    except KeyError:
                        self.idfs_score[token.item()] = 1

            self.idfs_score = {item[0]: np.log(tokens['input_ids'].shape[0] / item[1]) for item in self.idfs_score.items()}
        
        attention_mask = tokens['attention_mask']
        # Reshaping attenion mask
        mask = attention_mask.unsqueeze(-1).expand(embeddings.size()).float()
        # Applying attention mask
        masked_embeddings = embeddings * mask
        
        # Applying IDF to model word vectors
        for sent_ind in range(masked_embeddings.shape[0]):
            for word_ind in range(masked_embeddings.shape[1]):
                masked_embeddings[sent_ind][word_ind] *= self.idfs_score.get(tokens['input_ids'][sent_ind][word_ind].item(), 1)
        
        # Getting average vector
        summed = torch.sum(masked_embeddings, 1)

        summed_mask = torch.clamp(mask.sum(1), min=1e-9)

        text_vectors = summed / summed_mask

        return text_vectors

# %%
rubert_obj = RuBERT()
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased-conversational were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Text preprocessing
# Deleting stop words
rus_stop_words = stopwords.words('russian')

def del_stop_words(text):
    words = text.split(' ')
    return ' '.join([i for i in words if i not in rus_stop_words])

# %%
data.text[:20].apply(del_stop_words)
# Out:
# 0     Информации смартфоне Realme 9 4G, который перв...
# 1     Компания Qnap Systems представила серию хранил...
# 2     Как пишет Интерфакс ссылкой Центральное телеви...
# 3     Компания Samsung готовит ещё очень доступный с...
# 4     Компании Ford Motor General Motors (GM) следую...
# 5     С 4 апреля сети кинотеатров «Каро» начнут пока...
# 6     Как пишет ТАСС, Минобрнауки разослало вузам пи...
# 7     Разработчики бенчмарка AnTuTu опубликовали све...
# 8     Ассортимент компании Ugreen, специализирующейс...
# 9     Компании Epic Games, похоже, придётся отвечать...
# 10    Специалисты аналитической компании IDC подвели...
# 11    Компания EK, специализирующаяся выпуске компон...
# 12    Министерство цифрового развития, связи массовы...
# 13    Компания EK, специализирующаяся выпуске компон...
# 14    Мошенники начали активную рассылку электронных...
# 15    Робот Boston Dynamics Stretch, который способе...
# 16    Компания Google объявила запуске новой функции...
# 17    Компания Lenovo готовится пополнить ассортимен...
# 18    Как сегодня говорили, компания Apple активно и...
# 19    Известная своими компактными игровыми ноутбука...
# Name: text, dtype: object

# %% [markdown]
#     Now we can apply model and check it's performance

# %%
# %%time
text_embeddings = rubert_obj.get_embeddings(data.text[:20].apply(del_stop_words), update_idf=True)
# Out:
# Wall time: 53.7 s

# %%
cosine_similarities_dct = dict()

for i in range(text_embeddings.shape[0]):
    for j in range(i + 1, text_embeddings.shape[0]):
        first_vector = text_embeddings[i].detach().numpy().reshape(1, -1)
        second_vector = text_embeddings[j].detach().numpy().reshape(1, -1)
        cosine_similarities_dct[f'{i} - {j}'] = cosine_similarity(first_vector, second_vector)[0][0]

# %%
for pair, similarity in sorted(cosine_similarities_dct.items(), key=lambda x: x[1], reverse=True):
    print(f"Pair {pair} -> {similarity}")
# Out:
# Pair 3 - 17 -> 0.8810005187988281
# Pair 0 - 17 -> 0.8714632987976074
# Pair 8 - 13 -> 0.867717981338501
# Pair 0 - 3 -> 0.8672029972076416
# Pair 0 - 19 -> 0.8639278411865234
# Pair 3 - 19 -> 0.8625789880752563
# Pair 17 - 19 -> 0.8600724339485168
# Pair 8 - 19 -> 0.8469281792640686
# Pair 13 - 19 -> 0.8322530388832092
# Pair 1 - 19 -> 0.8299097418785095
# Pair 0 - 18 -> 0.8292346000671387
# Pair 1 - 13 -> 0.8220564126968384
# Pair 18 - 19 -> 0.8182384967803955
# Pair 1 - 8 -> 0.8169050812721252
# Pair 6 - 12 -> 0.8147690296173096
# Pair 3 - 18 -> 0.8141442537307739
# Pair 7 - 18 -> 0.8102940320968628
# Pair 0 - 8 -> 0.8045006990432739
# Pair 0 - 7 -> 0.8015919923782349
# Pair 17 - 18 -> 0.8015601634979248
# Pair 7 - 17 -> 0.8014261722564697
# Pair 3 - 7 -> 0.7962417602539062
# Pair 0 - 1 -> 0.7924342155456543
# Pair 10 - 18 -> 0.7919483184814453
# Pair 4 - 18 -> 0.791883111000061
# Pair 8 - 17 -> 0.7914964556694031
# Pair 1 - 3 -> 0.791325569152832
# Pair 0 - 16 -> 0.7889103889465332
# Pair 13 - 18 -> 0.788846492767334
# Pair 15 - 18 -> 0.7874094843864441
# Pair 8 - 18 -> 0.7867527008056641
# Pair 4 - 10 -> 0.7851165533065796
# Pair 7 - 19 -> 0.7848736643791199
# Pair 16 - 19 -> 0.7813361883163452
# Pair 1 - 17 -> 0.7762585878372192
# Pair 3 - 8 -> 0.7746305465698242
# Pair 0 - 13 -> 0.7730900049209595
# Pair 16 - 18 -> 0.7714639902114868
# Pair 8 - 10 -> 0.7710481286048889
# Pair 16 - 17 -> 0.7692369222640991
# Pair 9 - 18 -> 0.7686784267425537
# Pair 12 - 16 -> 0.768347978591919
# Pair 10 - 13 -> 0.7683051228523254
# Pair 8 - 9 -> 0.7647549510002136
# Pair 4 - 13 -> 0.7632018327713013
# Pair 10 - 19 -> 0.7629960775375366
# Pair 6 - 15 -> 0.7624334096908569
# Pair 4 - 19 -> 0.7607793211936951
# Pair 5 - 16 -> 0.759108304977417
# Pair 4 - 8 -> 0.7590438723564148
# Pair 13 - 17 -> 0.7590340375900269
# Pair 5 - 12 -> 0.7581890225410461
# Pair 3 - 16 -> 0.7579537034034729
# Pair 11 - 19 -> 0.7573860883712769
# Pair 1 - 4 -> 0.7558156251907349
# Pair 4 - 9 -> 0.7555906772613525
# Pair 0 - 4 -> 0.7551088333129883
# Pair 15 - 19 -> 0.7534727454185486
# Pair 12 - 15 -> 0.751268744468689
# Pair 4 - 15 -> 0.7495490312576294
# Pair 9 - 19 -> 0.7493083477020264
# Pair 11 - 15 -> 0.7490477561950684
# Pair 1 - 10 -> 0.7485675811767578
# Pair 4 - 7 -> 0.748354434967041
# Pair 13 - 15 -> 0.7478679418563843
# Pair 3 - 15 -> 0.7477051019668579
# Pair 15 - 16 -> 0.7463709712028503
# Pair 4 - 5 -> 0.7456517219543457
# Pair 11 - 13 -> 0.7452663779258728
# Pair 3 - 11 -> 0.7437502145767212
# Pair 15 - 17 -> 0.7435397505760193
# Pair 14 - 16 -> 0.7430437207221985
# Pair 8 - 16 -> 0.7420002818107605
# Pair 8 - 15 -> 0.741972804069519
# Pair 0 - 15 -> 0.7415075898170471
# Pair 3 - 13 -> 0.7412974834442139
# Pair 5 - 6 -> 0.7406938076019287
# Pair 3 - 4 -> 0.7378098368644714
# Pair 1 - 18 -> 0.7376410961151123
# Pair 12 - 13 -> 0.737289309501648
# Pair 7 - 8 -> 0.7371746301651001
# Pair 4 - 17 -> 0.7361088991165161
# Pair 3 - 10 -> 0.7358195185661316
# Pair 6 - 18 -> 0.7331488132476807
# Pair 9 - 13 -> 0.7321151494979858
# Pair 1 - 5 -> 0.7320013046264648
# Pair 5 - 18 -> 0.7319203019142151
# Pair 8 - 11 -> 0.7314163446426392
# Pair 5 - 19 -> 0.7303488254547119
# Pair 11 - 18 -> 0.7300927042961121
# Pair 5 - 13 -> 0.7282618284225464
# Pair 0 - 11 -> 0.7279163599014282
# Pair 0 - 5 -> 0.7269122004508972
# Pair 5 - 8 -> 0.726192831993103
# Pair 1 - 11 -> 0.7251976132392883
# Pair 7 - 10 -> 0.7236339449882507
# Pair 13 - 16 -> 0.723391056060791
# Pair 0 - 10 -> 0.7232884168624878
# Pair 12 - 18 -> 0.7227827310562134
# Pair 6 - 11 -> 0.7208880186080933
# Pair 2 - 15 -> 0.7205065488815308
# Pair 5 - 9 -> 0.7203786969184875
# Pair 6 - 16 -> 0.720001220703125
# Pair 9 - 10 -> 0.7192256450653076
# Pair 12 - 14 -> 0.7167457342147827
# Pair 4 - 6 -> 0.7167011499404907
# Pair 1 - 7 -> 0.7162271738052368
# Pair 7 - 11 -> 0.7159330248832703
# Pair 10 - 16 -> 0.7145917415618896
# Pair 9 - 16 -> 0.7137671709060669
# Pair 10 - 12 -> 0.7129214406013489
# Pair 7 - 9 -> 0.7122917175292969
# Pair 13 - 14 -> 0.7099563479423523
# Pair 11 - 17 -> 0.708500862121582
# Pair 5 - 7 -> 0.7061994671821594
# Pair 7 - 13 -> 0.7060786485671997
# Pair 0 - 9 -> 0.7053544521331787
# Pair 8 - 12 -> 0.7037152647972107
# Pair 4 - 11 -> 0.703622579574585
# Pair 6 - 9 -> 0.7035864591598511
# Pair 3 - 12 -> 0.7026249170303345
# Pair 10 - 15 -> 0.7023255825042725
# Pair 8 - 14 -> 0.701846718788147
# Pair 5 - 17 -> 0.7012345194816589
# Pair 2 - 6 -> 0.6999682188034058
# Pair 3 - 9 -> 0.698486328125
# Pair 14 - 18 -> 0.6977987289428711
# Pair 9 - 14 -> 0.6976015567779541
# Pair 5 - 14 -> 0.6975209712982178
# Pair 3 - 6 -> 0.696980357170105
# Pair 4 - 16 -> 0.6965923309326172
# Pair 11 - 12 -> 0.6948009729385376
# Pair 5 - 10 -> 0.6947358846664429
# Pair 9 - 15 -> 0.694390058517456
# Pair 3 - 5 -> 0.6926184892654419
# Pair 7 - 15 -> 0.6922252178192139
# Pair 2 - 18 -> 0.6920185089111328
# Pair 9 - 11 -> 0.6917546987533569
# Pair 1 - 16 -> 0.6915296912193298
# Pair 5 - 15 -> 0.6914563775062561
# Pair 6 - 8 -> 0.6909675598144531
# Pair 10 - 17 -> 0.6907817125320435
# Pair 12 - 19 -> 0.6906343698501587
# Pair 2 - 12 -> 0.6888689994812012
# Pair 14 - 15 -> 0.6883755922317505
# Pair 6 - 19 -> 0.686977744102478
# Pair 6 - 14 -> 0.6852675676345825
# Pair 6 - 10 -> 0.6849815845489502
# Pair 1 - 15 -> 0.6849333047866821
# Pair 7 - 16 -> 0.6840064525604248
# Pair 10 - 11 -> 0.6821267604827881
# Pair 5 - 11 -> 0.6819738149642944
# Pair 2 - 10 -> 0.6809936761856079
# Pair 1 - 9 -> 0.6808468103408813
# Pair 6 - 13 -> 0.6806828379631042
# Pair 10 - 14 -> 0.6801120042800903
# Pair 6 - 17 -> 0.674922525882721
# Pair 6 - 7 -> 0.674382209777832
# Pair 12 - 17 -> 0.6735517978668213
# Pair 1 - 12 -> 0.6725988388061523
# Pair 0 - 14 -> 0.6705189347267151
# Pair 0 - 6 -> 0.6699709892272949
# Pair 9 - 12 -> 0.6693723797798157
# Pair 9 - 17 -> 0.6680538058280945
# Pair 0 - 12 -> 0.6658623218536377
# Pair 4 - 14 -> 0.6634860038757324
# Pair 2 - 13 -> 0.663158655166626
# Pair 4 - 12 -> 0.6617493033409119
# Pair 2 - 17 -> 0.6607412695884705
# Pair 11 - 16 -> 0.6567015647888184
# Pair 2 - 8 -> 0.6554676294326782
# Pair 7 - 12 -> 0.6540777683258057
# Pair 14 - 19 -> 0.6533526182174683
# Pair 2 - 3 -> 0.6520469784736633
# Pair 1 - 14 -> 0.6483994126319885
# Pair 1 - 6 -> 0.6461456418037415
# Pair 2 - 19 -> 0.643187403678894
# Pair 2 - 4 -> 0.637749433517456
# Pair 2 - 11 -> 0.6341862082481384
# Pair 2 - 5 -> 0.6334867477416992
# Pair 3 - 14 -> 0.6328647136688232
# Pair 2 - 7 -> 0.6266471147537231
# Pair 2 - 9 -> 0.6243399381637573
# Pair 0 - 2 -> 0.6167687773704529
# Pair 14 - 17 -> 0.6135281324386597
# Pair 1 - 2 -> 0.6107215881347656
# Pair 2 - 16 -> 0.6032626032829285
# Pair 11 - 14 -> 0.6012167930603027
# Pair 7 - 14 -> 0.5946089029312134
# Pair 2 - 14 -> 0.5701941251754761

# %%
syntatic_text = "Samsung готовит ещё один очень бюджетный смартфон. Galaxy F13 уже засветился в Geekbench, что" +\
"позволяет нам заодно узнать его основные параметры. "       +\
"При тестах платформа набирает 157 и 587 баллов в однопоточном и многопоточном режимах соответственно. При этом у " +\
"этого тестового аппарата было 4 ГБ оперативной памяти. Например Galaxy F12 "        +\
"основан на той же платформе и имеет тот же объём памяти. То есть с точки зрения производительности разницы не будет "        +\
"вообще никакой. Если теория подтвердится и Galaxy F13 будет копией Galaxy A13, то экран увеличится, а ёмкость аккумулятора снизится."

# %%
syntatic_text
# Out:
# 'Samsung готовит ещё один очень бюджетный смартфон. Galaxy F13 уже засветился в Geekbench, чтопозволяет нам заодно узнать его основные параметры. При тестах платформа набирает 157 и 587 баллов в однопоточном и многопоточном режимах соответственно. При этом у этого тестового аппарата было 4 ГБ оперативной памяти. Например Galaxy F12 основан на той же платформе и имеет тот же объём памяти. То есть с точки зрения производительности разницы не будет вообще никакой. Если теория подтвердится и Galaxy F13 будет копией Galaxy A13, то экран увеличится, а ёмкость аккумулятора снизится.'

# %%
# %%time
syn_embed = rubert_obj.get_embeddings([del_stop_words(syntatic_text)], update_idf=False)
# Out:
# Wall time: 3.39 s

# %%
syn_cosine_similarities_dct = dict()
text_embed_with_syn = torch.vstack([text_embeddings, syn_embed])

for i in range(text_embed_with_syn.shape[0]):
    for j in range(i + 1, text_embed_with_syn.shape[0]):
        first_vector = text_embed_with_syn[i].detach().numpy().reshape(1, -1)
        second_vector = text_embed_with_syn[j].detach().numpy().reshape(1, -1)
        syn_cosine_similarities_dct[f'{i} - {j}'] = {
            "Cosine measure": cosine_similarity(first_vector, second_vector)[0][0],
            "Manhattan distance": manhattan_distances(first_vector, second_vector)[0][0],
            "Euclidian distance": euclidean_distances(first_vector, second_vector)[0][0],
        }

# %%
for pair, similarity in sorted(syn_cosine_similarities_dct.items(), key=lambda x: x[1]["Cosine measure"], reverse=True):
    print(f"Pair {pair} -> {similarity}")
# Out:
# Pair 3 - 20 -> {'Cosine measure': 0.9236032, 'Manhattan distance': 162.6966446529259, 'Euclidian distance': 7.3434963}
# Pair 3 - 17 -> {'Cosine measure': 0.8810005, 'Manhattan distance': 208.67742345348233, 'Euclidian distance': 9.483934}
# Pair 0 - 17 -> {'Cosine measure': 0.8714633, 'Manhattan distance': 219.12258523446508, 'Euclidian distance': 9.88745}
# Pair 8 - 13 -> {'Cosine measure': 0.867718, 'Manhattan distance': 237.280664157297, 'Euclidian distance': 10.9142885}
# Pair 0 - 3 -> {'Cosine measure': 0.867203, 'Manhattan distance': 210.03540116612567, 'Euclidian distance': 9.566016}
# Pair 0 - 19 -> {'Cosine measure': 0.86392784, 'Manhattan distance': 212.8782062981627, 'Euclidian distance': 9.671088}
# Pair 3 - 19 -> {'Cosine measure': 0.862579, 'Manhattan distance': 207.311513835215, 'Euclidian distance': 9.616859}
# Pair 17 - 19 -> {'Cosine measure': 0.86007243, 'Manhattan distance': 222.3967786655412, 'Euclidian distance': 10.255882}
# Pair 8 - 19 -> {'Cosine measure': 0.8469282, 'Manhattan distance': 235.56640665681334, 'Euclidian distance': 10.897865}
# Pair 13 - 19 -> {'Cosine measure': 0.83225304, 'Manhattan distance': 266.13989667315036, 'Euclidian distance': 12.053565}
# Pair 1 - 19 -> {'Cosine measure': 0.82990974, 'Manhattan distance': 264.7655248788069, 'Euclidian distance': 12.065598}
# Pair 0 - 18 -> {'Cosine measure': 0.8292346, 'Manhattan distance': 243.79377969156485, 'Euclidian distance': 11.0318165}
# Pair 1 - 13 -> {'Cosine measure': 0.8220564, 'Manhattan distance': 281.9684249563725, 'Euclidian distance': 12.932311}
# Pair 18 - 19 -> {'Cosine measure': 0.8182385, 'Manhattan distance': 247.42225834500277, 'Euclidian distance': 11.273337}
# Pair 1 - 8 -> {'Cosine measure': 0.8169051, 'Manhattan distance': 277.6718673076248, 'Euclidian distance': 12.766195}
# Pair 6 - 12 -> {'Cosine measure': 0.814769, 'Manhattan distance': 260.95774254907155, 'Euclidian distance': 11.769104}
# Pair 3 - 18 -> {'Cosine measure': 0.81414425, 'Manhattan distance': 251.98618727602297, 'Euclidian distance': 11.412607}
# Pair 0 - 20 -> {'Cosine measure': 0.8128764, 'Manhattan distance': 254.52032403030898, 'Euclidian distance': 11.559316}
# Pair 7 - 18 -> {'Cosine measure': 0.81029403, 'Manhattan distance': 265.85883198538795, 'Euclidian distance': 12.255446}
# Pair 0 - 8 -> {'Cosine measure': 0.8045007, 'Manhattan distance': 272.60201551241335, 'Euclidian distance': 12.337474}
# Pair 0 - 7 -> {'Cosine measure': 0.801592, 'Manhattan distance': 275.0029076045612, 'Euclidian distance': 12.473951}
# Pair 17 - 18 -> {'Cosine measure': 0.80156016, 'Manhattan distance': 268.75433928205166, 'Euclidian distance': 12.316774}
# Pair 7 - 17 -> {'Cosine measure': 0.8014262, 'Manhattan distance': 281.4510460385354, 'Euclidian distance': 12.768132}
# Pair 3 - 7 -> {'Cosine measure': 0.79624176, 'Manhattan distance': 275.6075995823485, 'Euclidian distance': 12.574546}
# Pair 0 - 1 -> {'Cosine measure': 0.7924342, 'Manhattan distance': 292.9296642993577, 'Euclidian distance': 13.281692}
# Pair 10 - 18 -> {'Cosine measure': 0.7919483, 'Manhattan distance': 273.0491945735412, 'Euclidian distance': 12.361559}
# Pair 4 - 18 -> {'Cosine measure': 0.7918831, 'Manhattan distance': 291.01715639047325, 'Euclidian distance': 13.174974}
# Pair 19 - 20 -> {'Cosine measure': 0.7915453, 'Manhattan distance': 262.725517098268, 'Euclidian distance': 12.082968}
# Pair 8 - 17 -> {'Cosine measure': 0.79149646, 'Manhattan distance': 285.6711801189231, 'Euclidian distance': 13.044968}
# Pair 1 - 3 -> {'Cosine measure': 0.79132557, 'Manhattan distance': 290.7357408645912, 'Euclidian distance': 13.276515}
# Pair 18 - 20 -> {'Cosine measure': 0.7899778, 'Manhattan distance': 270.0016933600418, 'Euclidian distance': 12.334195}
# Pair 0 - 16 -> {'Cosine measure': 0.7889104, 'Manhattan distance': 285.7801971687004, 'Euclidian distance': 12.692669}
# Pair 13 - 18 -> {'Cosine measure': 0.7888465, 'Manhattan distance': 291.8479606168694, 'Euclidian distance': 13.489582}
# Pair 17 - 20 -> {'Cosine measure': 0.7887063, 'Manhattan distance': 284.0675591643667, 'Euclidian distance': 12.716051}
# Pair 15 - 18 -> {'Cosine measure': 0.7874095, 'Manhattan distance': 267.2894372897572, 'Euclidian distance': 12.224512}
# Pair 8 - 18 -> {'Cosine measure': 0.7867527, 'Manhattan distance': 285.9307417329401, 'Euclidian distance': 12.937609}
# Pair 4 - 10 -> {'Cosine measure': 0.78511655, 'Manhattan distance': 294.51772107591387, 'Euclidian distance': 13.434225}
# Pair 7 - 19 -> {'Cosine measure': 0.78487366, 'Manhattan distance': 287.9058395163738, 'Euclidian distance': 12.901331}
# Pair 16 - 19 -> {'Cosine measure': 0.7813362, 'Manhattan distance': 278.9178244363866, 'Euclidian distance': 12.826116}
# Pair 1 - 17 -> {'Cosine measure': 0.7762586, 'Manhattan distance': 304.7704977791291, 'Euclidian distance': 13.997914}
# Pair 3 - 8 -> {'Cosine measure': 0.77463055, 'Manhattan distance': 288.79394682176644, 'Euclidian distance': 13.155755}
# Pair 0 - 13 -> {'Cosine measure': 0.77309, 'Manhattan distance': 303.1089836701867, 'Euclidian distance': 13.921846}
# Pair 16 - 18 -> {'Cosine measure': 0.771464, 'Manhattan distance': 293.48042691790033, 'Euclidian distance': 13.272538}
# Pair 8 - 10 -> {'Cosine measure': 0.7710481, 'Manhattan distance': 292.35358239046764, 'Euclidian distance': 13.474278}
# Pair 16 - 17 -> {'Cosine measure': 0.7692369, 'Manhattan distance': 298.2544788552914, 'Euclidian distance': 13.624318}
# Pair 9 - 18 -> {'Cosine measure': 0.7686784, 'Manhattan distance': 292.7872138203238, 'Euclidian distance': 13.268112}
# Pair 12 - 16 -> {'Cosine measure': 0.768348, 'Manhattan distance': 300.48497767187655, 'Euclidian distance': 13.626629}
# Pair 10 - 13 -> {'Cosine measure': 0.7683051, 'Manhattan distance': 313.62726429855684, 'Euclidian distance': 14.155414}
# Pair 8 - 9 -> {'Cosine measure': 0.76475495, 'Manhattan distance': 303.0447513689869, 'Euclidian distance': 13.836536}
# Pair 4 - 13 -> {'Cosine measure': 0.76320183, 'Manhattan distance': 322.9418112276471, 'Euclidian distance': 14.809182}
# Pair 10 - 19 -> {'Cosine measure': 0.7629961, 'Manhattan distance': 285.78795307531254, 'Euclidian distance': 12.983674}
# Pair 6 - 15 -> {'Cosine measure': 0.7624334, 'Manhattan distance': 278.28290743241087, 'Euclidian distance': 12.740819}
# Pair 4 - 19 -> {'Cosine measure': 0.7607793, 'Manhattan distance': 306.8808158331667, 'Euclidian distance': 13.975172}
# Pair 5 - 16 -> {'Cosine measure': 0.7591083, 'Manhattan distance': 312.99550780747086, 'Euclidian distance': 14.251214}
# Pair 4 - 8 -> {'Cosine measure': 0.7590439, 'Manhattan distance': 314.30769362696446, 'Euclidian distance': 14.492522}
# Pair 13 - 17 -> {'Cosine measure': 0.75903404, 'Manhattan distance': 317.524546323868, 'Euclidian distance': 14.5741}
# Pair 5 - 12 -> {'Cosine measure': 0.758189, 'Manhattan distance': 316.7697962070815, 'Euclidian distance': 14.213555}
# Pair 3 - 16 -> {'Cosine measure': 0.7579537, 'Manhattan distance': 301.1797959112446, 'Euclidian distance': 13.493772}
# Pair 11 - 19 -> {'Cosine measure': 0.7573861, 'Manhattan distance': 284.30813178332755, 'Euclidian distance': 12.998093}
# Pair 1 - 4 -> {'Cosine measure': 0.7558156, 'Manhattan distance': 328.033545278362, 'Euclidian distance': 14.992852}
# Pair 4 - 9 -> {'Cosine measure': 0.7555907, 'Manhattan distance': 316.34686066542054, 'Euclidian distance': 14.459841}
# Pair 0 - 4 -> {'Cosine measure': 0.75510883, 'Manhattan distance': 312.281624643947, 'Euclidian distance': 14.203795}
# Pair 15 - 19 -> {'Cosine measure': 0.75347275, 'Manhattan distance': 284.48038011661265, 'Euclidian distance': 12.907363}
# Pair 12 - 15 -> {'Cosine measure': 0.75126874, 'Manhattan distance': 303.5684608654701, 'Euclidian distance': 13.594151}
# Pair 4 - 15 -> {'Cosine measure': 0.74954903, 'Manhattan distance': 308.3469017166062, 'Euclidian distance': 14.30685}
# Pair 9 - 19 -> {'Cosine measure': 0.74930835, 'Manhattan distance': 297.4121131824795, 'Euclidian distance': 13.620018}
# Pair 11 - 15 -> {'Cosine measure': 0.74904776, 'Manhattan distance': 288.4663015570841, 'Euclidian distance': 13.259612}
# Pair 1 - 10 -> {'Cosine measure': 0.7485676, 'Manhattan distance': 321.6483157523908, 'Euclidian distance': 14.669083}
# Pair 4 - 7 -> {'Cosine measure': 0.74835443, 'Manhattan distance': 329.84468982182443, 'Euclidian distance': 14.84198}
# Pair 13 - 15 -> {'Cosine measure': 0.74786794, 'Manhattan distance': 322.7481143657351, 'Euclidian distance': 14.595681}
# Pair 3 - 15 -> {'Cosine measure': 0.7477051, 'Manhattan distance': 287.59521580301225, 'Euclidian distance': 13.076175}
# Pair 15 - 16 -> {'Cosine measure': 0.746371, 'Manhattan distance': 306.9246547334478, 'Euclidian distance': 13.825866}
# Pair 4 - 5 -> {'Cosine measure': 0.7456517, 'Manhattan distance': 330.89827754336875, 'Euclidian distance': 15.042129}
# Pair 11 - 13 -> {'Cosine measure': 0.7452664, 'Manhattan distance': 323.23874615860404, 'Euclidian distance': 14.754941}
# Pair 3 - 11 -> {'Cosine measure': 0.7437502, 'Manhattan distance': 293.7358262503403, 'Euclidian distance': 13.374534}
# Pair 15 - 17 -> {'Cosine measure': 0.74353975, 'Manhattan distance': 303.0344817179139, 'Euclidian distance': 13.834161}
# Pair 14 - 16 -> {'Cosine measure': 0.7430437, 'Manhattan distance': 350.5976715368565, 'Euclidian distance': 15.832151}
# Pair 8 - 16 -> {'Cosine measure': 0.7420003, 'Manhattan distance': 319.1639778696699, 'Euclidian distance': 14.55944}
# Pair 8 - 15 -> {'Cosine measure': 0.7419728, 'Manhattan distance': 309.51457226328785, 'Euclidian distance': 14.072838}
# Pair 0 - 15 -> {'Cosine measure': 0.7415076, 'Manhattan distance': 295.6999668285134, 'Euclidian distance': 13.367098}
# Pair 3 - 13 -> {'Cosine measure': 0.7412975, 'Manhattan distance': 325.5220224666409, 'Euclidian distance': 14.763449}
# Pair 7 - 20 -> {'Cosine measure': 0.74087685, 'Manhattan distance': 313.9797164243646, 'Euclidian distance': 14.304014}
# Pair 5 - 6 -> {'Cosine measure': 0.7406938, 'Manhattan distance': 315.15865429496625, 'Euclidian distance': 14.359502}
# Pair 3 - 4 -> {'Cosine measure': 0.73780984, 'Manhattan distance': 325.15052492235554, 'Euclidian distance': 14.611551}
# Pair 1 - 18 -> {'Cosine measure': 0.7376411, 'Manhattan distance': 325.13454771845136, 'Euclidian distance': 14.914249}
# Pair 12 - 13 -> {'Cosine measure': 0.7372893, 'Manhattan distance': 337.5256758182659, 'Euclidian distance': 15.189554}
# Pair 7 - 8 -> {'Cosine measure': 0.73717463, 'Manhattan distance': 325.87982643721625, 'Euclidian distance': 14.831596}
# Pair 4 - 17 -> {'Cosine measure': 0.7361089, 'Manhattan distance': 332.28832621045876, 'Euclidian distance': 15.037331}
# Pair 3 - 10 -> {'Cosine measure': 0.7358195, 'Manhattan distance': 304.57684561627684, 'Euclidian distance': 13.720016}
# Pair 6 - 18 -> {'Cosine measure': 0.7331488, 'Manhattan distance': 304.34295529761584, 'Euclidian distance': 13.718226}
# Pair 9 - 13 -> {'Cosine measure': 0.73211515, 'Manhattan distance': 337.4804801068967, 'Euclidian distance': 15.339526}
# Pair 1 - 5 -> {'Cosine measure': 0.7320013, 'Manhattan distance': 340.41134534822777, 'Euclidian distance': 15.572853}
# Pair 5 - 18 -> {'Cosine measure': 0.7319203, 'Manhattan distance': 323.9772498678649, 'Euclidian distance': 14.710834}
# Pair 8 - 11 -> {'Cosine measure': 0.73141634, 'Manhattan distance': 314.35448455112055, 'Euclidian distance': 14.487903}
# Pair 5 - 19 -> {'Cosine measure': 0.7303488, 'Manhattan distance': 319.9294931641198, 'Euclidian distance': 14.591177}
# Pair 11 - 18 -> {'Cosine measure': 0.7300927, 'Manhattan distance': 302.93009932222776, 'Euclidian distance': 13.950899}
# Pair 5 - 13 -> {'Cosine measure': 0.7282618, 'Manhattan distance': 347.5036831299658, 'Euclidian distance': 15.730986}
# Pair 0 - 11 -> {'Cosine measure': 0.72791636, 'Manhattan distance': 302.5878709779354, 'Euclidian distance': 13.903681}
# Pair 0 - 5 -> {'Cosine measure': 0.7269122, 'Manhattan distance': 330.07562689320184, 'Euclidian distance': 14.774505}
# Pair 5 - 8 -> {'Cosine measure': 0.72619283, 'Manhattan distance': 333.6459761833539, 'Euclidian distance': 15.283287}
# Pair 1 - 11 -> {'Cosine measure': 0.7251976, 'Manhattan distance': 325.43322688213084, 'Euclidian distance': 15.242195}
# Pair 7 - 10 -> {'Cosine measure': 0.72363394, 'Manhattan distance': 322.95522134180646, 'Euclidian distance': 14.842211}
# Pair 13 - 16 -> {'Cosine measure': 0.72339106, 'Manhattan distance': 339.44197772309417, 'Euclidian distance': 15.641109}
# Pair 0 - 10 -> {'Cosine measure': 0.7232884, 'Manhattan distance': 315.84346670052037, 'Euclidian distance': 14.156802}
# Pair 12 - 18 -> {'Cosine measure': 0.72278273, 'Manhattan distance': 324.9874853665242, 'Euclidian distance': 14.513887}
# Pair 6 - 11 -> {'Cosine measure': 0.720888, 'Manhattan distance': 301.29340950917685, 'Euclidian distance': 14.008875}
# Pair 2 - 15 -> {'Cosine measure': 0.72050655, 'Manhattan distance': 312.0947128201951, 'Euclidian distance': 14.2355585}
# Pair 5 - 9 -> {'Cosine measure': 0.7203787, 'Manhattan distance': 332.7567661109497, 'Euclidian distance': 15.283561}
# Pair 6 - 16 -> {'Cosine measure': 0.7200012, 'Manhattan distance': 322.53158857667586, 'Euclidian distance': 14.537608}
# Pair 9 - 10 -> {'Cosine measure': 0.71922565, 'Manhattan distance': 322.3798604120384, 'Euclidian distance': 14.7074175}
# Pair 12 - 14 -> {'Cosine measure': 0.71674573, 'Manhattan distance': 362.46048036882394, 'Euclidian distance': 16.547674}
# Pair 4 - 6 -> {'Cosine measure': 0.71670115, 'Manhattan distance': 331.38016169547336, 'Euclidian distance': 15.197612}
# Pair 1 - 7 -> {'Cosine measure': 0.7162272, 'Manhattan distance': 347.57872209989, 'Euclidian distance': 15.9010725}
# Pair 7 - 11 -> {'Cosine measure': 0.715933, 'Manhattan distance': 325.79643327300437, 'Euclidian distance': 14.944907}
# Pair 10 - 16 -> {'Cosine measure': 0.71459174, 'Manhattan distance': 323.25091933924705, 'Euclidian distance': 14.915185}
# Pair 9 - 16 -> {'Cosine measure': 0.7137672, 'Manhattan distance': 329.0320340351318, 'Euclidian distance': 15.1513405}
# Pair 10 - 12 -> {'Cosine measure': 0.71292144, 'Manhattan distance': 326.60446548089385, 'Euclidian distance': 14.866129}
# Pair 7 - 9 -> {'Cosine measure': 0.7122917, 'Manhattan distance': 336.86621088936226, 'Euclidian distance': 15.343832}
# Pair 13 - 14 -> {'Cosine measure': 0.70995635, 'Manhattan distance': 375.5283912653799, 'Euclidian distance': 17.200502}
# Pair 11 - 17 -> {'Cosine measure': 0.70850086, 'Manhattan distance': 321.80252370086964, 'Euclidian distance': 14.896724}
# Pair 5 - 7 -> {'Cosine measure': 0.70619947, 'Manhattan distance': 350.33473667374346, 'Euclidian distance': 15.869385}
# Pair 7 - 13 -> {'Cosine measure': 0.70607865, 'Manhattan distance': 354.98277962760767, 'Euclidian distance': 16.235567}
# Pair 16 - 20 -> {'Cosine measure': 0.7056166, 'Manhattan distance': 332.39690900954884, 'Euclidian distance': 15.063108}
# Pair 0 - 9 -> {'Cosine measure': 0.70535445, 'Manhattan distance': 325.6389229077031, 'Euclidian distance': 14.875006}
# Pair 8 - 12 -> {'Cosine measure': 0.70371526, 'Manhattan distance': 338.3866121539613, 'Euclidian distance': 15.521778}
# Pair 4 - 11 -> {'Cosine measure': 0.7036226, 'Manhattan distance': 339.54380092723295, 'Euclidian distance': 15.639678}
# Pair 6 - 9 -> {'Cosine measure': 0.70358646, 'Manhattan distance': 328.76785661210306, 'Euclidian distance': 14.855044}
# Pair 3 - 12 -> {'Cosine measure': 0.7026249, 'Manhattan distance': 327.13531226600753, 'Euclidian distance': 14.827743}
# Pair 10 - 15 -> {'Cosine measure': 0.7023256, 'Manhattan distance': 318.07574470859254, 'Euclidian distance': 14.58495}
# Pair 8 - 14 -> {'Cosine measure': 0.7018467, 'Manhattan distance': 373.80083212467116, 'Euclidian distance': 17.071054}
# Pair 5 - 17 -> {'Cosine measure': 0.7012345, 'Manhattan distance': 345.4927958508488, 'Euclidian distance': 15.816291}
# Pair 8 - 20 -> {'Cosine measure': 0.7007221, 'Manhattan distance': 338.81503791944124, 'Euclidian distance': 15.312126}
# Pair 2 - 6 -> {'Cosine measure': 0.6999682, 'Manhattan distance': 324.6715480146813, 'Euclidian distance': 14.771134}
# Pair 3 - 9 -> {'Cosine measure': 0.6984863, 'Manhattan distance': 325.76347491669003, 'Euclidian distance': 14.935422}
# Pair 14 - 18 -> {'Cosine measure': 0.6977987, 'Manhattan distance': 370.223113646975, 'Euclidian distance': 16.900608}
# Pair 9 - 14 -> {'Cosine measure': 0.69760156, 'Manhattan distance': 374.13811672753627, 'Euclidian distance': 17.078001}
# Pair 5 - 14 -> {'Cosine measure': 0.697521, 'Manhattan distance': 381.36219078873955, 'Euclidian distance': 17.314127}
# Pair 3 - 6 -> {'Cosine measure': 0.69698036, 'Manhattan distance': 317.7042169769993, 'Euclidian distance': 14.3605995}
# Pair 4 - 16 -> {'Cosine measure': 0.69659233, 'Manhattan distance': 356.8419518385781, 'Euclidian distance': 16.163933}
# Pair 10 - 20 -> {'Cosine measure': 0.6948546, 'Manhattan distance': 328.44377979717683, 'Euclidian distance': 14.982475}
# Pair 11 - 12 -> {'Cosine measure': 0.694801, 'Manhattan distance': 334.4652791650733, 'Euclidian distance': 15.2088}
# Pair 5 - 10 -> {'Cosine measure': 0.6947359, 'Manhattan distance': 349.1474566590041, 'Euclidian distance': 15.768312}
# Pair 9 - 15 -> {'Cosine measure': 0.69439006, 'Manhattan distance': 332.85782509983983, 'Euclidian distance': 15.058232}
# Pair 3 - 5 -> {'Cosine measure': 0.6926185, 'Manhattan distance': 338.44396315707127, 'Euclidian distance': 15.562329}
# Pair 7 - 15 -> {'Cosine measure': 0.6922252, 'Manhattan distance': 340.03447836771375, 'Euclidian distance': 15.399083}
# Pair 2 - 18 -> {'Cosine measure': 0.6920185, 'Manhattan distance': 328.7319508079672, 'Euclidian distance': 15.136147}
# Pair 9 - 11 -> {'Cosine measure': 0.6917547, 'Manhattan distance': 336.2386566491914, 'Euclidian distance': 15.289807}
# Pair 1 - 16 -> {'Cosine measure': 0.6915297, 'Manhattan distance': 358.4323039785959, 'Euclidian distance': 16.451054}
# Pair 5 - 15 -> {'Cosine measure': 0.6914564, 'Manhattan distance': 349.49510503729107, 'Euclidian distance': 15.6100025}
# Pair 6 - 8 -> {'Cosine measure': 0.69096756, 'Manhattan distance': 336.22375006315997, 'Euclidian distance': 15.398146}
# Pair 10 - 17 -> {'Cosine measure': 0.6907817, 'Manhattan distance': 345.0283310452942, 'Euclidian distance': 15.458972}
# Pair 12 - 19 -> {'Cosine measure': 0.69063437, 'Manhattan distance': 337.57715675694635, 'Euclidian distance': 15.104247}
# Pair 2 - 12 -> {'Cosine measure': 0.688869, 'Manhattan distance': 342.68358664843254, 'Euclidian distance': 15.5617}
# Pair 14 - 15 -> {'Cosine measure': 0.6883756, 'Manhattan distance': 371.4743503836912, 'Euclidian distance': 17.055626}
# Pair 15 - 20 -> {'Cosine measure': 0.6870444, 'Manhattan distance': 321.56848649139283, 'Euclidian distance': 14.841905}
# Pair 6 - 19 -> {'Cosine measure': 0.68697774, 'Manhattan distance': 323.60525039723143, 'Euclidian distance': 14.574973}
# Pair 1 - 20 -> {'Cosine measure': 0.68540883, 'Manhattan distance': 359.60845184640493, 'Euclidian distance': 16.299232}
# Pair 6 - 14 -> {'Cosine measure': 0.68526757, 'Manhattan distance': 374.08638604851467, 'Euclidian distance': 17.144934}
# Pair 6 - 10 -> {'Cosine measure': 0.6849816, 'Manhattan distance': 323.1333598611527, 'Euclidian distance': 15.029058}
# Pair 1 - 15 -> {'Cosine measure': 0.6849333, 'Manhattan distance': 352.85771004128037, 'Euclidian distance': 16.16486}
# Pair 7 - 16 -> {'Cosine measure': 0.68400645, 'Manhattan distance': 354.29907950700726, 'Euclidian distance': 16.156685}
# Pair 10 - 11 -> {'Cosine measure': 0.68212676, 'Manhattan distance': 329.40938673878554, 'Euclidian distance': 15.258731}
# Pair 5 - 11 -> {'Cosine measure': 0.6819738, 'Manhattan distance': 346.9593802449526, 'Euclidian distance': 15.987187}
# Pair 2 - 10 -> {'Cosine measure': 0.6809937, 'Manhattan distance': 336.2201111682225, 'Euclidian distance': 15.514277}
# Pair 1 - 9 -> {'Cosine measure': 0.6808468, 'Manhattan distance': 360.15569591120584, 'Euclidian distance': 16.665113}
# Pair 6 - 13 -> {'Cosine measure': 0.68068284, 'Manhattan distance': 364.34408309170976, 'Euclidian distance': 16.354597}
# Pair 10 - 14 -> {'Cosine measure': 0.680112, 'Manhattan distance': 375.1343399925504, 'Euclidian distance': 17.413147}
# Pair 13 - 20 -> {'Cosine measure': 0.67955357, 'Manhattan distance': 364.257048939995, 'Euclidian distance': 16.510962}
# Pair 4 - 20 -> {'Cosine measure': 0.676867, 'Manhattan distance': 358.8963948020246, 'Euclidian distance': 16.339752}
# Pair 6 - 17 -> {'Cosine measure': 0.6749225, 'Manhattan distance': 349.0117860615137, 'Euclidian distance': 15.579486}
# Pair 6 - 7 -> {'Cosine measure': 0.6743822, 'Manhattan distance': 347.7122715549194, 'Euclidian distance': 15.853708}
# Pair 12 - 17 -> {'Cosine measure': 0.6735518, 'Manhattan distance': 357.24559901305474, 'Euclidian distance': 16.114819}
# Pair 11 - 20 -> {'Cosine measure': 0.67270434, 'Manhattan distance': 336.8346146289259, 'Euclidian distance': 15.3768835}
# Pair 1 - 12 -> {'Cosine measure': 0.67259884, 'Manhattan distance': 372.76683894218877, 'Euclidian distance': 16.872877}
# Pair 0 - 14 -> {'Cosine measure': 0.67051893, 'Manhattan distance': 387.64909850818776, 'Euclidian distance': 17.547565}
# Pair 0 - 6 -> {'Cosine measure': 0.669971, 'Manhattan distance': 334.8742102179094, 'Euclidian distance': 15.133038}
# Pair 9 - 12 -> {'Cosine measure': 0.6693724, 'Manhattan distance': 353.08526608831016, 'Euclidian distance': 16.193018}
# Pair 9 - 17 -> {'Cosine measure': 0.6680538, 'Manhattan distance': 354.21216390276095, 'Euclidian distance': 16.255024}
# Pair 0 - 12 -> {'Cosine measure': 0.6658623, 'Manhattan distance': 352.76220975862816, 'Euclidian distance': 15.828632}
# Pair 4 - 14 -> {'Cosine measure': 0.663486, 'Manhattan distance': 399.5222621061953, 'Euclidian distance': 18.367188}
# Pair 2 - 13 -> {'Cosine measure': 0.66315866, 'Manhattan distance': 377.9293383360491, 'Euclidian distance': 17.057825}
# Pair 4 - 12 -> {'Cosine measure': 0.6617493, 'Manhattan distance': 374.25841686862987, 'Euclidian distance': 16.985485}
# Pair 2 - 17 -> {'Cosine measure': 0.66074127, 'Manhattan distance': 357.59341486450285, 'Euclidian distance': 16.281012}
# Pair 11 - 16 -> {'Cosine measure': 0.65670156, 'Manhattan distance': 356.0501678705914, 'Euclidian distance': 16.229847}
# Pair 2 - 8 -> {'Cosine measure': 0.6554676, 'Manhattan distance': 366.8686832204694, 'Euclidian distance': 16.596346}
# Pair 7 - 12 -> {'Cosine measure': 0.65407777, 'Manhattan distance': 376.57436175772455, 'Euclidian distance': 16.817738}
# Pair 14 - 19 -> {'Cosine measure': 0.6533526, 'Manhattan distance': 390.3280257991978, 'Euclidian distance': 17.892725}
# Pair 9 - 20 -> {'Cosine measure': 0.6530969, 'Manhattan distance': 357.7247415544116, 'Euclidian distance': 16.248545}
# Pair 2 - 3 -> {'Cosine measure': 0.652047, 'Manhattan distance': 348.43147852428956, 'Euclidian distance': 15.847614}
# Pair 1 - 14 -> {'Cosine measure': 0.6483994, 'Manhattan distance': 413.53333046439775, 'Euclidian distance': 18.882378}
# Pair 1 - 6 -> {'Cosine measure': 0.64614564, 'Manhattan distance': 376.5127649522037, 'Euclidian distance': 17.114931}
# Pair 2 - 19 -> {'Cosine measure': 0.6431874, 'Manhattan distance': 351.15083808702184, 'Euclidian distance': 16.027674}
# Pair 2 - 4 -> {'Cosine measure': 0.63774943, 'Manhattan distance': 379.152718465426, 'Euclidian distance': 17.444489}
# Pair 12 - 20 -> {'Cosine measure': 0.6367149, 'Manhattan distance': 365.02093282330316, 'Euclidian distance': 16.620817}
# Pair 2 - 11 -> {'Cosine measure': 0.6341862, 'Manhattan distance': 359.30801347165834, 'Euclidian distance': 16.474121}
# Pair 2 - 5 -> {'Cosine measure': 0.63348675, 'Manhattan distance': 378.54034137842245, 'Euclidian distance': 17.347378}
# Pair 3 - 14 -> {'Cosine measure': 0.6328647, 'Manhattan distance': 402.5791411295763, 'Euclidian distance': 18.384958}
# Pair 2 - 7 -> {'Cosine measure': 0.6266471, 'Manhattan distance': 378.85081051976886, 'Euclidian distance': 17.32547}
# Pair 6 - 20 -> {'Cosine measure': 0.6265921, 'Manhattan distance': 360.22327450144803, 'Euclidian distance': 16.240664}
# Pair 2 - 9 -> {'Cosine measure': 0.62433994, 'Manhattan distance': 374.23314234340796, 'Euclidian distance': 17.104322}
# Pair 0 - 2 -> {'Cosine measure': 0.6167688, 'Manhattan distance': 369.2504695553798, 'Euclidian distance': 16.766956}
# Pair 2 - 20 -> {'Cosine measure': 0.616367, 'Manhattan distance': 372.5467852948932, 'Euclidian distance': 16.90563}
# Pair 14 - 17 -> {'Cosine measure': 0.61352813, 'Manhattan distance': 422.44021291182116, 'Euclidian distance': 19.243145}
# Pair 1 - 2 -> {'Cosine measure': 0.6107216, 'Manhattan distance': 398.4446963707451, 'Euclidian distance': 18.252155}
# Pair 5 - 20 -> {'Cosine measure': 0.6060487, 'Manhattan distance': 388.8238174893195, 'Euclidian distance': 17.799461}
# Pair 2 - 16 -> {'Cosine measure': 0.6032626, 'Manhattan distance': 385.91107609379105, 'Euclidian distance': 17.674568}
# Pair 11 - 14 -> {'Cosine measure': 0.6012168, 'Manhattan distance': 422.2765120498484, 'Euclidian distance': 19.25102}
# Pair 7 - 14 -> {'Cosine measure': 0.5946089, 'Manhattan distance': 432.7902940618919, 'Euclidian distance': 19.866669}
# Pair 14 - 20 -> {'Cosine measure': 0.58034945, 'Manhattan distance': 429.41668037046884, 'Euclidian distance': 19.747623}
# Pair 2 - 14 -> {'Cosine measure': 0.5701941, 'Manhattan distance': 445.96123459552155, 'Euclidian distance': 20.12151}

# %% [markdown]
# ### Results
#
#     RuBERT model works very slow, and it's not a good idea to use it for text vectorization
